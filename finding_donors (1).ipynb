# %% [markdown]
# ## Supervised Learning
# ## Project: Finding Donors for *CharityML*

# %% [markdown]
# In this notebook, some template code has already been provided for you, and it will be your job to implement the additional functionality necessary to successfully complete this project. Sections that begin with **'Implementation'** in the header indicate that the following block of code will require additional functionality which you must provide. Instructions will be provided for each section and the specifics of the implementation are marked in the code block with a `'TODO'` statement. Please be sure to read the instructions carefully!
#
# In addition to implementing code, there will be questions that you must answer which relate to the project and your implementation. Each section where you will answer a question is preceded by a **'Question X'** header. Carefully read each question and provide thorough answers in the following text boxes that begin with **'Answer:'**. Your project submission will be evaluated based on your answers to each of the questions and the implementation you provide.
#
# >**Note:** Please specify WHICH VERSION OF PYTHON you are using when submitting this notebook. Code and Markdown cells can be executed using the **Shift + Enter** keyboard shortcut. In addition, Markdown cells can be edited by typically double-clicking the cell to enter edit mode.

# %% [markdown]
# ## Getting Started
#
# In this project, you will employ several supervised algorithms of your choice to accurately model individuals' income using data collected from the 1994 U.S. Census. You will then choose the best candidate algorithm from preliminary results and further optimize this algorithm to best model the data. Your goal with this implementation is to construct a model that accurately predicts whether an individual makes more than $50,000. This sort of task can arise in a non-profit setting, where organizations survive on donations.  Understanding an individual's income can help a non-profit better understand how large of a donation to request, or whether or not they should reach out to begin with.  While it can be difficult to determine an individual's general income bracket directly from public sources, we can (as we will see) infer this value from other publically available features.
#
# The dataset for this project originates from the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Census+Income). The datset was donated by Ron Kohavi and Barry Becker, after being published in the article _"Scaling Up the Accuracy of Naive-Bayes Classifiers: A Decision-Tree Hybrid"_. You can find the article by Ron Kohavi [online](https://www.aaai.org/Papers/KDD/1996/KDD96-033.pdf). The data we investigate here consists of small changes to the original dataset, such as removing the `'fnlwgt'` feature and records with missing or ill-formatted entries.

# %% [markdown]
# ----
# ## Exploring the Data
# Run the code cell below to load necessary Python libraries and load the census data. Note that the last column from this dataset, `'income'`, will be our target label (whether an individual makes more than, or at most, $50,000 annually). All other columns are features about each individual in the census database.

# %%
# Import libraries necessary for this project
import numpy as np
import pandas as pd
from time import time
from IPython.display import display # Allows the use of display() for DataFrames

# Import supplementary visualization code visuals.py
import visuals as vs

# Pretty display for notebooks
# %matplotlib inline

# Load the Census dataset
data = pd.read_csv("census.csv")

# Success - Display the first record
# display(data.head(n=1))
data.head()
# Out:
#    age          workclass education_level  education-num       marital-status  \
# 0   39          State-gov       Bachelors           13.0        Never-married
# 1   50   Self-emp-not-inc       Bachelors           13.0   Married-civ-spouse
# 2   38            Private         HS-grad            9.0             Divorced
# 3   53            Private            11th            7.0   Married-civ-spouse
# 4   28            Private       Bachelors           13.0   Married-civ-spouse
#
#            occupation    relationship    race      sex  capital-gain  \
# 0        Adm-clerical   Not-in-family   White     Male        2174.0
# 1     Exec-managerial         Husband   White     Male           0.0
# 2   Handlers-cleaners   Not-in-family   White     Male           0.0
# 3   Handlers-cleaners         Husband   Black     Male           0.0
# 4      Prof-specialty            Wife   Black   Female           0.0
#
#    capital-loss  hours-per-week  native-country income
# 0           0.0            40.0   United-States  <=50K
# 1           0.0            13.0   United-States  <=50K
# 2           0.0            40.0   United-States  <=50K
# 3           0.0            40.0   United-States  <=50K
# 4           0.0            40.0            Cuba  <=50K

# %% [markdown]
# ### Implementation: Data Exploration
# A cursory investigation of the dataset will determine how many individuals fit into either group, and will tell us about the percentage of these individuals making more than \$50,000. In the code cell below, you will need to compute the following:
# - The total number of records, `'n_records'`
# - The number of individuals making more than \$50,000 annually, `'n_greater_50k'`.
# - The number of individuals making at most \$50,000 annually, `'n_at_most_50k'`.
# - The percentage of individuals making more than \$50,000 annually, `'greater_percent'`.
#
# ** HINT: ** You may need to look at the table above to understand how the `'income'` entries are formatted.

# %%
# TODO: Total number of records
n_records = data.shape[0]

# TODO: Number of records where individual's income is more than $50,000
n_greater_50k = data[data["income"] == ">50K"].shape[0]

# TODO: Number of records where individual's income is at most $50,000
n_at_most_50k = data[data["income"] == "<=50K"].shape[0]

# TODO: Percentage of individuals whose income is more than $50,000
greater_percent = n_greater_50k/n_records

# Print the results
print("Total number of records: {}".format(n_records))
print("Individuals making more than $50,000: {}".format(n_greater_50k))
print("Individuals making at most $50,000: {}".format(n_at_most_50k))
print("Percentage of individuals making more than $50,000: {}%".format(greater_percent))
# Out:
# Total number of records: 45222
# Individuals making more than $50,000: 11208
# Individuals making at most $50,000: 34014
# Percentage of individuals making more than $50,000: 0.2478439697492371%

# %% [markdown]
# ** Featureset Exploration **
#
# * **age**: continuous.
# * **workclass**: Private, Self-emp-not-inc, Self-emp-inc, Federal-gov, Local-gov, State-gov, Without-pay, Never-worked.
# * **education**: Bachelors, Some-college, 11th, HS-grad, Prof-school, Assoc-acdm, Assoc-voc, 9th, 7th-8th, 12th, Masters, 1st-4th, 10th, Doctorate, 5th-6th, Preschool.
# * **education-num**: continuous.
# * **marital-status**: Married-civ-spouse, Divorced, Never-married, Separated, Widowed, Married-spouse-absent, Married-AF-spouse.
# * **occupation**: Tech-support, Craft-repair, Other-service, Sales, Exec-managerial, Prof-specialty, Handlers-cleaners, Machine-op-inspct, Adm-clerical, Farming-fishing, Transport-moving, Priv-house-serv, Protective-serv, Armed-Forces.
# * **relationship**: Wife, Own-child, Husband, Not-in-family, Other-relative, Unmarried.
# * **race**: Black, White, Asian-Pac-Islander, Amer-Indian-Eskimo, Other.
# * **sex**: Female, Male.
# * **capital-gain**: continuous.
# * **capital-loss**: continuous.
# * **hours-per-week**: continuous.
# * **native-country**: United-States, Cambodia, England, Puerto-Rico, Canada, Germany, Outlying-US(Guam-USVI-etc), India, Japan, Greece, South, China, Cuba, Iran, Honduras, Philippines, Italy, Poland, Jamaica, Vietnam, Mexico, Portugal, Ireland, France, Dominican-Republic, Laos, Ecuador, Taiwan, Haiti, Columbia, Hungary, Guatemala, Nicaragua, Scotland, Thailand, Yugoslavia, El-Salvador, Trinadad&Tobago, Peru, Hong, Holand-Netherlands.

# %% [markdown]
# ----
# ## Preparing the Data
# Before data can be used as input for machine learning algorithms, it often must be cleaned, formatted, and restructured — this is typically known as **preprocessing**. Fortunately, for this dataset, there are no invalid or missing entries we must deal with, however, there are some qualities about certain features that must be adjusted. This preprocessing can help tremendously with the outcome and predictive power of nearly all learning algorithms.

# %% [markdown]
# ### Transforming Skewed Continuous Features
# A dataset may sometimes contain at least one feature whose values tend to lie near a single number, but will also have a non-trivial number of vastly larger or smaller values than that single number.  Algorithms can be sensitive to such distributions of values and can underperform if the range is not properly normalized. With the census dataset two features fit this description: '`capital-gain'` and `'capital-loss'`.
#
# Run the code cell below to plot a histogram of these two features. Note the range of the values present and how they are distributed.

# %%
# Split the data into features and target label
income_raw = data['income']
features_raw = data.drop('income', axis = 1)

# Visualize skewed continuous features of original data
vs.distribution(data)
# Out:
# c:\zakamaka\CIS\ML Week\visuals.py:48: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %% [markdown]
# For highly-skewed feature distributions such as `'capital-gain'` and `'capital-loss'`, it is common practice to apply a <a href="https://en.wikipedia.org/wiki/Data_transformation_(statistics)">logarithmic transformation</a> on the data so that the very large and very small values do not negatively affect the performance of a learning algorithm. Using a logarithmic transformation significantly reduces the range of values caused by outliers. Care must be taken when applying this transformation however: The logarithm of `0` is undefined, so we must translate the values by a small amount above `0` to apply the the logarithm successfully.
#
# Run the code cell below to perform a transformation on the data and visualize the results. Again, note the range of values and how they are distributed.

# %%
# Log-transform the skewed features
skewed = ['capital-gain', 'capital-loss']
features_log_transformed = pd.DataFrame(data = features_raw)
features_log_transformed[skewed] = features_raw[skewed].apply(lambda x: np.log(x + 1))

# Visualize the new log distributions
vs.distribution(features_log_transformed, transformed = True)
# Out:
# c:\zakamaka\CIS\ML Week\visuals.py:48: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %% [markdown]
# ### Normalizing Numerical Features
# In addition to performing transformations on features that are highly skewed, it is often good practice to perform some type of scaling on numerical features. Applying a scaling to the data does not change the shape of each feature's distribution (such as `'capital-gain'` or `'capital-loss'` above); however, normalization ensures that each feature is treated equally when applying supervised learners. Note that once scaling is applied, observing the data in its raw form will no longer have the same original meaning, as exampled below.
#
# Run the code cell below to normalize each numerical feature. We will use [`sklearn.preprocessing.MinMaxScaler`](http://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.MinMaxScaler.html) for this.

# %%
# Import sklearn.preprocessing.StandardScaler
from sklearn.preprocessing import MinMaxScaler

# Initialize a scaler, then apply it to the features
scaler = MinMaxScaler() # default=(0, 1)
numerical = ['age', 'education-num', 'capital-gain', 'capital-loss', 'hours-per-week']

features_log_minmax_transform = pd.DataFrame(data = features_log_transformed)
features_log_minmax_transform[numerical] = scaler.fit_transform(features_log_transformed[numerical])

# Show an example of a record with scaling applied
display(features_log_minmax_transform.head(n = 5))
# Out:
#         age          workclass education_level  education-num  \
# 0  0.301370          State-gov       Bachelors       0.800000
# 1  0.452055   Self-emp-not-inc       Bachelors       0.800000
# 2  0.287671            Private         HS-grad       0.533333
# 3  0.493151            Private            11th       0.400000
# 4  0.150685            Private       Bachelors       0.800000
#
#         marital-status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital-gain  capital-loss  hours-per-week  native-country
# 0      0.667492           0.0        0.397959   United-States
# 1      0.000000           0.0        0.122449   United-States
# 2      0.000000           0.0        0.397959   United-States
# 3      0.000000           0.0        0.397959   United-States
# 4      0.000000           0.0        0.397959            Cuba

# %% [markdown]
# ### Implementation: Data Preprocessing
#
# From the table in **Exploring the Data** above, we can see there are several features for each record that are non-numeric. Typically, learning algorithms expect input to be numeric, which requires that non-numeric features (called *categorical variables*) be converted. One popular way to convert categorical variables is by using the **one-hot encoding** scheme. One-hot encoding creates a _"dummy"_ variable for each possible category of each non-numeric feature. For example, assume `someFeature` has three possible entries: `A`, `B`, or `C`. We then encode this feature into `someFeature_A`, `someFeature_B` and `someFeature_C`.
#
# |   | someFeature |                    | someFeature_A | someFeature_B | someFeature_C |
# | :-: | :-: |                            | :-: | :-: | :-: |
# | 0 |  B  |  | 0 | 1 | 0 |
# | 1 |  C  | ----> one-hot encode ----> | 0 | 0 | 1 |
# | 2 |  A  |  | 1 | 0 | 0 |
#
# Additionally, as with the non-numeric features, we need to convert the non-numeric target label, `'income'` to numerical values for the learning algorithm to work. Since there are only two possible categories for this label ("<=50K" and ">50K"), we can avoid using one-hot encoding and simply encode these two categories as `0` and `1`, respectively. In code cell below, you will need to implement the following:
#  - Use [`pandas.get_dummies()`](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.get_dummies.html?highlight=get_dummies#pandas.get_dummies) to perform one-hot encoding on the `'features_log_minmax_transform'` data.
#  - Convert the target label `'income_raw'` to numerical entries.
#    - Set records with "<=50K" to `0` and records with ">50K" to `1`.

# %%
income_raw.head()
# Out:
# 0    <=50K
# 1    <=50K
# 2    <=50K
# 3    <=50K
# 4    <=50K
# Name: income, dtype: object

# %%
# TODO: One-hot encode the 'features_log_minmax_transform' data using pandas.get_dummies()
l = list(features_log_minmax_transform.columns)
for i in numerical:
    l.remove(i)
    
features_final = pd.get_dummies(data=features_log_minmax_transform, columns=l)
# features_final = features_log_minmax_transform
# # TODO: Encode the 'income_raw' data to numerical values
income_raw = pd.DataFrame(income_raw)
income_raw['income'] = income_raw['income'].replace(['<=50K'], 0)
income_raw['income'] = income_raw['income'].replace(['>50K'],1)
income = income_raw

# Print the number of features after one-hot encoding
encoded = list(features_final.columns)
print("{} total features after one-hot encoding.".format(len(encoded)))

# Uncomment the following line to see the encoded feature names
# print encoded
# Out:
# 103 total features after one-hot encoding.

# %%
income.head()
# Out:
#    income
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %% [markdown]
# ### Shuffle and Split Data
# Now all _categorical variables_ have been converted into numerical features, and all numerical features have been normalized. As always, we will now split the data (both features and their labels) into training and test sets. 80% of the data will be used for training and 20% for testing.
#
# Run the code cell below to perform this split.

# %%
# Import train_test_split
from sklearn.model_selection import train_test_split

# Split the 'features' and 'income' data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(features_final, 
                                                    income, 
                                                    test_size = 0.2, 
                                                    random_state = 0)

# Show the results of the split
print("Training set has {} samples.".format(X_train.shape[0]))
print("Testing set has {} samples.".format(X_test.shape[0]))
# Out:
# Training set has 36177 samples.
# Testing set has 9045 samples.

# %% [markdown]
# *Note: this Workspace is running on `sklearn` v0.19. If you use the newer version (>="0.20"), the `sklearn.cross_validation` has been replaced with `sklearn.model_selection`.*

# %% [markdown]
# ----
# ## Evaluating Model Performance
# In this section, we will investigate four different algorithms, and determine which is best at modeling the data. Three of these algorithms will be supervised learners of your choice, and the fourth algorithm is known as a *naive predictor*.

# %% [markdown]
# ### Metrics and the Naive Predictor
# *CharityML*, equipped with their research, knows individuals that make more than \$50,000 are most likely to donate to their charity. Because of this, *CharityML* is particularly interested in predicting who makes more than \$50,000 accurately. It would seem that using **accuracy** as a metric for evaluating a particular model's performace would be appropriate. Additionally, identifying someone that *does not* make more than \$50,000 as someone who does would be detrimental to *CharityML*, since they are looking to find individuals willing to donate. Therefore, a model's ability to precisely predict those that make more than \$50,000 is *more important* than the model's ability to **recall** those individuals. We can use **F-beta score** as a metric that considers both precision and recall:
#
# $$ F_{\beta} = (1 + \beta^2) \cdot \frac{precision \cdot recall}{\left( \beta^2 \cdot precision \right) + recall} $$
#
# In particular, when $\beta = 0.5$, more emphasis is placed on precision. This is called the **F$_{0.5}$ score** (or F-score for simplicity).
#
# Looking at the distribution of classes (those who make at most \$50,000, and those who make more), it's clear most individuals do not make more than \$50,000. This can greatly affect **accuracy**, since we could simply say *"this person does not make more than \$50,000"* and generally be right, without ever looking at the data! Making such a statement would be called **naive**, since we have not considered any information to substantiate the claim. It is always important to consider the *naive prediction* for your data, to help establish a benchmark for whether a model is performing well. That been said, using that prediction would be pointless: If we predicted all people made less than \$50,000, *CharityML* would identify no one as donors.
#
#
# #### Note: Recap of accuracy, precision, recall
#
# ** Accuracy ** measures how often the classifier makes the correct prediction. It’s the ratio of the number of correct predictions to the total number of predictions (the number of test data points).
#
# ** Precision ** tells us what proportion of messages we classified as spam, actually were spam.
# It is a ratio of true positives(words classified as spam, and which are actually spam) to all positives(all words classified as spam, irrespective of whether that was the correct classificatio), in other words it is the ratio of
#
# `[True Positives/(True Positives + False Positives)]`
#
# ** Recall(sensitivity)** tells us what proportion of messages that actually were spam were classified by us as spam.
# It is a ratio of true positives(words classified as spam, and which are actually spam) to all the words that were actually spam, in other words it is the ratio of
#
# `[True Positives/(True Positives + False Negatives)]`
#
# For classification problems that are skewed in their classification distributions like in our case, for example if we had a 100 text messages and only 2 were spam and the rest 98 weren't, accuracy by itself is not a very good metric. We could classify 90 messages as not spam(including the 2 that were spam but we classify them as not spam, hence they would be false negatives) and 10 as spam(all 10 false positives) and still get a reasonably good accuracy score. For such cases, precision and recall come in very handy. These two metrics can be combined to get the F1 score, which is weighted average(harmonic mean) of the precision and recall scores. This score can range from 0 to 1, with 1 being the best possible F1 score(we take the harmonic mean as we are dealing with ratios).

# %% [markdown]
# ### Question 1 - Naive Predictor Performace
# * If we chose a model that always predicted an individual made more than $50,000, what would  that model's accuracy and F-score be on this dataset? You must use the code cell below and assign your results to `'accuracy'` and `'fscore'` to be used later.
#
# ** Please note ** that the the purpose of generating a naive predictor is simply to show what a base model without any intelligence would look like. In the real world, ideally your base model would be either the results of a previous model or could be based on a research paper upon which you are looking to improve. When there is no benchmark model set, getting a result better than random choice is a place you could start from.
#
# ** HINT: **
#
# * When we have a model that always predicts '1' (i.e. the individual makes more than 50k) then our model will have no True Negatives(TN) or False Negatives(FN) as we are not making any negative('0' value) predictions. Therefore our Accuracy in this case becomes the same as our Precision(True Positives/(True Positives + False Positives)) as every prediction that we have made with value '1' that should have '0' becomes a False Positive; therefore our denominator in this case is the total number of records we have in total.
# * Our Recall score(True Positives/(True Positives + False Negatives)) in this setting becomes 1 as we have no False Negatives.

# %%
'''
TP = np.sum(income) # Counting the ones as this is the naive case. Note that 'income' is the 'income_raw' data 
encoded to numerical values done in the data preprocessing step.
FP = income.count() - TP # Specific to the naive case

TN = 0 # No predicted negatives in the naive case
FN = 0 # No predicted negatives in the naive case
'''
TP = int(np.sum(income))
FP = int(income.count())-TP
FN = 0
TN = 0
# TODO: Calculate accuracy, precision and recall
accuracy = TP/(TP+FP)
recall = TP/(TP+FN)
precision = TP/(TP+FP)
# TODO: Calculate F-score using the formula above for beta = 0.5 and correct values for precision and recall.
beta = 0.5
fscore = (1+(beta**2))*((precision*recall)/(((beta**2)*precision)+recall))
# Print the results 
print("Naive Predictor: [Accuracy score: {:.4f}, F-score: {:.4f}]".format(accuracy, fscore))
# Out:
# Naive Predictor: [Accuracy score: 0.2478, F-score: 0.2917]

# %%
X_train.head()
# Out:
#             age  education-num  capital-gain  capital-loss  hours-per-week  \
# 13181  0.410959       0.600000           0.0      0.000000        0.500000
# 10342  0.438356       0.533333           0.0      0.000000        0.397959
# 20881  0.054795       0.666667           0.0      0.000000        0.357143
# 24972  0.301370       0.866667           0.0      0.905759        0.448980
# 43867  0.246575       0.600000           0.0      0.000000        0.500000
#
#        workclass_ Federal-gov  workclass_ Local-gov  workclass_ Private  \
# 13181                       0                     0                   1
# 10342                       0                     0                   1
# 20881                       0                     0                   1
# 24972                       0                     1                   0
# 43867                       0                     0                   1
#
#        workclass_ Self-emp-inc  workclass_ Self-emp-not-inc  ...  \
# 13181                        0                            0  ...
# 10342                        0                            0  ...
# 20881                        0                            0  ...
# 24972                        0                            0  ...
# 43867                        0                            0  ...
#
#        native-country_ Portugal  native-country_ Puerto-Rico  \
# 13181                         0                            0
# 10342                         0                            0
# 20881                         0                            0
# 24972                         0                            0
# 43867                         0                            0
#
#        native-country_ Scotland  native-country_ South  \
# 13181                         0                      0
# 10342                         0                      0
# 20881                         0                      0
# 24972                         0                      0
# 43867                         0                      0
#
#        native-country_ Taiwan  native-country_ Thailand  \
# 13181                       0                         0
# 10342                       0                         0
# 20881                       0                         0
# 24972                       0                         0
# 43867                       0                         0
#
#        native-country_ Trinadad&Tobago  native-country_ United-States  \
# 13181                                0                              1
# 10342                                0                              1
# 20881                                0                              1
# 24972                                0                              1
# 43867                                0                              1
#
#        native-country_ Vietnam  native-country_ Yugoslavia
# 13181                        0                           0
# 10342                        0                           0
# 20881                        0                           0
# 24972                        0                           0
# 43867                        0                           0
#
# [5 rows x 103 columns]

# %% [markdown]
# ###  Supervised Learning Models
# **The following are some of the supervised learning models that are currently available in** [`scikit-learn`](http://scikit-learn.org/stable/supervised_learning.html) **that you may choose from:**
# - Gaussian Naive Bayes (GaussianNB)
# - Decision Trees
# - Ensemble Methods (Bagging, AdaBoost, Random Forest, Gradient Boosting)
# - K-Nearest Neighbors (KNeighbors)
# - Stochastic Gradient Descent Classifier (SGDC)
# - Support Vector Machines (SVM)
# - Logistic Regression

# %% [markdown]
# ### Question 2 - Model Application
# List three of the supervised learning models above that are appropriate for this problem that you will test on the census data. For each model chosen
#
# - Describe one real-world application in industry where the model can be applied.
# - What are the strengths of the model; when does it perform well?
# - What are the weaknesses of the model; when does it perform poorly?
# - What makes this model a good candidate for the problem, given what you know about the data?
#
# ** HINT: **
#
# Structure your answer in the same format as above^, with 4 parts for each of the three models you pick. Please include references with your answer.

# %% [markdown]
# **Answer: **
# 1) logistic regression:
# - binary classification problems like spam or not spam.
# - Performs well on low-dimensional data, when the dataset has features that are linearly separable.
# - Assumes linearity between dependent and independent variables, When it fails to capture complex relationships.
# - because it works with continuous data and is used for binary data
# 2) Light GBM:
# - Fraud detection is a critical application in the finance and banking industries, as it helps identify fraudulent activities that can cause financial loss.
# - Faster training speed and higher efficiency, when the dataset is large
# - Overfitting:Light GBM is sensitive to overfitting and thus can easily overfit small data.
# - becuase it is one of the best algorithms when the data is not too small
# 3)
# - Recommendation systems , Fraud detection, Image classification, Text classification, Customer churn prediction, Medical diagnoses,NLP
# - CatBoost can automatically convert categorical features into numerical features, when the dataset is large.
# - Overfitting:Light GBM is sensitive to overfitting and thus can easily overfit small data.
# - because it was specifically designed to handle categorical features

# %% [markdown]
# ### Implementation - Creating a Training and Predicting Pipeline
# To properly evaluate the performance of each model you've chosen, it's important that you create a training and predicting pipeline that allows you to quickly and effectively train models using various sizes of training data and perform predictions on the testing data. Your implementation here will be used in the following section.
# In the code block below, you will need to implement the following:
#  - Import `fbeta_score` and `accuracy_score` from [`sklearn.metrics`](http://scikit-learn.org/stable/modules/classes.html#sklearn-metrics-metrics).
#  - Fit the learner to the sampled training data and record the training time.
#  - Perform predictions on the test data `X_test`, and also on the first 300 training points `X_train[:300]`.
#    - Record the total prediction time.
#  - Calculate the accuracy score for both the training subset and testing set.
#  - Calculate the F-score for both the training subset and testing set.
#    - Make sure that you set the `beta` parameter!

# %%
# TODO: Import two metrics from sklearn - fbeta_score and accuracy_score
from sklearn.metrics import fbeta_score, accuracy_score
def train_predict(learner, sample_size, X_train, y_train, X_test, y_test):
    '''
    inputs:
       - learner: the learning algorithm to be trained and predicted on
       - sample_size: the size of samples (number) to be drawn from training set
       - X_train: features training set
       - y_train: income training set
       - X_test: features testing set
       - y_test: income testing set
    '''
    
    results = {}
    # TODO: Fit the learner to the training data using slicing with 'sample_size' using .fit(training_features[:], training_labels[:])
    start = time() # Get start time
    learner.fit(X_train[:sample_size], y_train[:sample_size])
    end = time() # Get end time
    
    # TODO: Calculate the training time
    results['train_time'] = end - start
        
    # TODO: Get the predictions on the test set(X_test),
    #       then get predictions on the first 300 training samples(X_train) using .predict()
    start = time() # Get start time
    predictions_test = learner.predict(X_test)
    predictions_train = learner.predict(X_train[:300])
    end = time() # Get end time
    
    # TODO: Calculate the total prediction time
    results['pred_time'] = end - start
            
    # TODO: Compute accuracy on the first 300 training samples which is y_train[:300]
    results['acc_train'] = accuracy_score(y_train[:300],predictions_train)
        
    # TODO: Compute accuracy on test set using accuracy_score()
    results['acc_test'] = accuracy_score(y_test,predictions_test)
    
    # TODO: Compute F-score on the the first 300 training samples using fbeta_score()
    results['f_train'] = fbeta_score(y_train[:300],predictions_train,beta=0.5)
        
    # TODO: Compute F-score on the test set which is y_test
    results['f_test'] = fbeta_score(y_test,predictions_test,beta=0.5)
       
    # Success
    print("{} trained on {} samples.".format(learner.__class__.__name__, sample_size))
        
    # Return the results
    return results

# %% [markdown]
# ### Implementation: Initial Model Evaluation
# In the code cell, you will need to implement the following:
# - Import the three supervised learning models you've discussed in the previous section.
# - Initialize the three models and store them in `'clf_A'`, `'clf_B'`, and `'clf_C'`.
#   - Use a `'random_state'` for each model you use, if provided.
#   - **Note:** Use the default settings for each model — you will tune one specific model in a later section.
# - Calculate the number of records equal to 1%, 10%, and 100% of the training data.
#   - Store those values in `'samples_1'`, `'samples_10'`, and `'samples_100'` respectively.
#
# **Note:** Depending on which algorithms you chose, the following implementation may take some time to run!

# %%
X_train.head()
# Out:
#             age  education-num  capital-gain  capital-loss  hours-per-week  \
# 13181  0.410959       0.600000           0.0      0.000000        0.500000
# 10342  0.438356       0.533333           0.0      0.000000        0.397959
# 20881  0.054795       0.666667           0.0      0.000000        0.357143
# 24972  0.301370       0.866667           0.0      0.905759        0.448980
# 43867  0.246575       0.600000           0.0      0.000000        0.500000
#
#        workclass_ Federal-gov  workclass_ Local-gov  workclass_ Private  \
# 13181                       0                     0                   1
# 10342                       0                     0                   1
# 20881                       0                     0                   1
# 24972                       0                     1                   0
# 43867                       0                     0                   1
#
#        workclass_ Self-emp-inc  workclass_ Self-emp-not-inc  ...  \
# 13181                        0                            0  ...
# 10342                        0                            0  ...
# 20881                        0                            0  ...
# 24972                        0                            0  ...
# 43867                        0                            0  ...
#
#        native-country_ Portugal  native-country_ Puerto-Rico  \
# 13181                         0                            0
# 10342                         0                            0
# 20881                         0                            0
# 24972                         0                            0
# 43867                         0                            0
#
#        native-country_ Scotland  native-country_ South  \
# 13181                         0                      0
# 10342                         0                      0
# 20881                         0                      0
# 24972                         0                      0
# 43867                         0                      0
#
#        native-country_ Taiwan  native-country_ Thailand  \
# 13181                       0                         0
# 10342                       0                         0
# 20881                       0                         0
# 24972                       0                         0
# 43867                       0                         0
#
#        native-country_ Trinadad&Tobago  native-country_ United-States  \
# 13181                                0                              1
# 10342                                0                              1
# 20881                                0                              1
# 24972                                0                              1
# 43867                                0                              1
#
#        native-country_ Vietnam  native-country_ Yugoslavia
# 13181                        0                           0
# 10342                        0                           0
# 20881                        0                           0
# 24972                        0                           0
# 43867                        0                           0
#
# [5 rows x 103 columns]

# %%
# TODO: Import the three supervised learning models from sklearn
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from xgboost import XGBClassifier
import lightgbm as lgb
from catboost import CatBoostClassifier
# TODO: Initialize the three models

clf_A = LogisticRegression(max_iter=10000)
clf_B = lgb.LGBMClassifier(n_estimators=250)
clf_C = CatBoostClassifier(logging_level='Silent')

# TODO: Calculate the number of samples for 1%, 10%, and 100% of the training data
# HINT: samples_100 is the entire training set i.e. len(y_train)
# HINT: samples_10 is 10% of samples_100 (ensure to set the count of the values to be `int` and not `float`)
# HINT: samples_1 is 1% of samples_100 (ensure to set the count of the values to be `int` and not `float`)
samples_100 = len(y_train)
samples_10 = samples_100//10
samples_1 = samples_100//100

# Collect results on the learners
results = {}
for clf in [clf_A, clf_B, clf_C]:
    clf_name = clf.__class__.__name__
    results[clf_name] = {}
    for i, samples in enumerate([samples_1, samples_10, samples_100]):
        results[clf_name][i] = \
        train_predict(clf, samples, X_train, y_train, X_test, y_test)

# Run metrics visualization for the three supervised learning models chosen
vs.evaluate(results, accuracy, fscore)
# Out:
# c:\Users\Gehan\anaconda3\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\Gehan\anaconda3\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression trained on 361 samples.
# LogisticRegression trained on 3617 samples.
# c:\Users\Gehan\anaconda3\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression trained on 36177 samples.
# c:\Users\Gehan\anaconda3\lib\site-packages\sklearn\preprocessing\_label.py:99: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\Gehan\anaconda3\lib\site-packages\sklearn\preprocessing\_label.py:134: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# LGBMClassifier trained on 361 samples.
# c:\Users\Gehan\anaconda3\lib\site-packages\sklearn\preprocessing\_label.py:99: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\Gehan\anaconda3\lib\site-packages\sklearn\preprocessing\_label.py:134: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# LGBMClassifier trained on 3617 samples.
# c:\Users\Gehan\anaconda3\lib\site-packages\sklearn\preprocessing\_label.py:99: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\Gehan\anaconda3\lib\site-packages\sklearn\preprocessing\_label.py:134: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# LGBMClassifier trained on 36177 samples.
# CatBoostClassifier trained on 361 samples.
# CatBoostClassifier trained on 3617 samples.
# CatBoostClassifier trained on 36177 samples.
# c:\zakamaka\CIS\ML Week\visuals.py:121: UserWarning: Tight layout not applied. tight_layout cannot make axes width small enough to accommodate all axes decorations
#   pl.tight_layout()

# %% [markdown]
# ----
# ## Improving Results
# In this final section, you will choose from the three supervised learning models the *best* model to use on the student data. You will then perform a grid search optimization for the model over the entire training set (`X_train` and `y_train`) by tuning at least one parameter to improve upon the untuned model's F-score.

# %% [markdown]
# ### Question 3 - Choosing the Best Model
#
# * Based on the evaluation you performed earlier, in one to two paragraphs, explain to *CharityML* which of the three models you believe to be most appropriate for the task of identifying individuals that make more than \$50,000.
#
# ** HINT: **
# Look at the graph at the bottom left from the cell above(the visualization created by `vs.evaluate(results, accuracy, fscore)`) and check the F score for the testing set when 100% of the training set is used. Which model has the highest score? Your answer should include discussion of the:
# * metrics - F score on the testing when 100% of the training data is used,
# * prediction/training time
# * the algorithm's suitability for the data.

# %% [markdown]
# **Answer: **
# - CAT and LGBM were close and a lot better than Logistic reg in the accuracy and fscore.
# - in the pridiction time LGBM was clearly worse than the other 2.
# - CAT is clearly the best model because it gets best accuracy and fscore in very short prediction time.

# %% [markdown]
# ### Question 4 - Describing the Model in Layman's Terms
#
# * In one to two paragraphs, explain to *CharityML*, in layman's terms, how the final model chosen is supposed to work. Be sure that you are describing the major qualities of the model, such as how the model is trained and how the model makes a prediction. Avoid using advanced mathematical jargon, such as describing equations.
#
# ** HINT: **
#
# When explaining your model, if using external resources please include all citations.

# %% [markdown]
# **Answer: **
# - CatBoost uses a number of techniques to improve the accuracy and efficiency of gradient boosting, including feature engineering, decision tree optimization and a novel algorithm called ordered boosting, it optimizes the learning objective function by permuting the features in a specific order. This approach can result in faster convergence and better model accuracy, especially for data sets with a large number of features.
# - To build the decision trees, CatBoost uses a technique called gradient-based optimization, where the trees are fitted to the loss function’s negative gradient. This approach allows the trees to focus on the regions of feature space that have the greatest impact on the loss function, thereby resulting in more accurate predictions.
# - https://builtin.com/machine-learning/catboost

# %% [markdown]
# ### Implementation: Model Tuning
# Fine tune the chosen model. Use grid search (`GridSearchCV`) with at least one important parameter tuned with at least 3 different values. You will need to use the entire training set for this. In the code cell below, you will need to implement the following:
# - Import [`sklearn.grid_search.GridSearchCV`](http://scikit-learn.org/0.17/modules/generated/sklearn.grid_search.GridSearchCV.html) and [`sklearn.metrics.make_scorer`](http://scikit-learn.org/stable/modules/generated/sklearn.metrics.make_scorer.html).
# - Initialize the classifier you've chosen and store it in `clf`.
#  - Set a `random_state` if one is available to the same state you set before.
# - Create a dictionary of parameters you wish to tune for the chosen model.
#  - Example: `parameters = {'parameter' : [list of values]}`.
#  - **Note:** Avoid tuning the `max_features` parameter of your learner if that parameter is available!
# - Use `make_scorer` to create an `fbeta_score` scoring object (with $\beta = 0.5$).
# - Perform grid search on the classifier `clf` using the `'scorer'`, and store it in `grid_obj`.
# - Fit the grid search object to the training data (`X_train`, `y_train`), and store it in `grid_fit`.
#
# **Note:** Depending on the algorithm chosen and the parameter list, the following implementation may take some time to run!

# %%
# TODO: Import 'GridSearchCV', 'make_scorer', and any other necessary libraries
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import make_scorer
from catboost import CatBoostClassifier

# TODO: Initialize the classifier
clf = CatBoostClassifier(logging_level='Silent')

# TODO: Create the parameters list you wish to tune, using a dictionary if needed.
# HINT: parameters = {'parameter_1': [value1, value2], 'parameter_2': [value1, value2]}
parameters = {'depth':[ x for x in range(2)]}

# TODO: Make an fbeta_score scoring object using make_scorer()
scorer = make_scorer(fbeta_score,beta=0.5)

# TODO: Perform grid search on the classifier using 'scorer' as the scoring method using GridSearchCV()
grid_obj = GridSearchCV(clf,parameters,scoring=scorer)

# TODO: Fit the grid search object to the training data and find the optimal parameters using fit()
grid_fit = grid_obj.fit(X_train,y_train)

# Get the estimator
best_clf = grid_fit.best_estimator_

# Make predictions using the unoptimized and model
predictions = (clf.fit(X_train, y_train)).predict(X_test)
best_predictions = best_clf.predict(X_test)

# Report the before-and-afterscores
print("Unoptimized model\n------")
print("Accuracy score on testing data: {:.4f}".format(accuracy_score(y_test, predictions)))
print("F-score on testing data: {:.4f}".format(fbeta_score(y_test, predictions, beta = 0.5)))
print("\nOptimized Model\n------")
print("Final accuracy score on the testing data: {:.4f}".format(accuracy_score(y_test, best_predictions)))
print("Final F-score on the testing data: {:.4f}".format(fbeta_score(y_test, best_predictions, beta = 0.5)))
# Out:
# Unoptimized model
# ------
# Accuracy score on testing data: 0.8725
# F-score on testing data: 0.7554
#
# Optimized Model
# ------
# Final accuracy score on the testing data: 0.8578
# Final F-score on the testing data: 0.7285

# %%
import numpy as np
import optuna
from optuna.integration import CatBoostPruningCallback

import catboost as cb
from sklearn.metrics import accuracy_score


def objective(trial: optuna.Trial) -> float:

    param = {
        "objective": trial.suggest_categorical("objective", ["Logloss", "CrossEntropy"]),
        "colsample_bylevel": trial.suggest_float("colsample_bylevel", 0.01, 0.1, log=True),
        "depth": trial.suggest_int("depth", 1, 12),
        "boosting_type": trial.suggest_categorical("boosting_type", ["Ordered", "Plain"]),
        "bootstrap_type": trial.suggest_categorical(
            "bootstrap_type", ["Bayesian", "Bernoulli", "MVS"]
        ),
        "used_ram_limit": "3gb",
        "eval_metric": "Accuracy",
    }

    if param["bootstrap_type"] == "Bayesian":
        param["bagging_temperature"] = trial.suggest_float("bagging_temperature", 0, 10)
    elif param["bootstrap_type"] == "Bernoulli":
        param["subsample"] = trial.suggest_float("subsample", 0.1, 1, log=True)

    gbm = cb.CatBoostClassifier(**param)

    pruning_callback = CatBoostPruningCallback(trial, "Accuracy")
    gbm.fit(
        X_train,
        y_train,
        eval_set=[(X_test, y_test)],
        verbose=0,
        early_stopping_rounds=100,
        callbacks=[pruning_callback],
    )

    # evoke pruning manually.
    pruning_callback.check_pruned()

    preds = gbm.predict(X_test)
    pred_labels = np.rint(preds)
    accuracy = accuracy_score(y_test, pred_labels)
    fb = fbeta_score(y_test,pred_labels,beta=0.5)

    return fb


study = optuna.create_study(
    pruner=optuna.pruners.MedianPruner(n_warmup_steps=5), direction="maximize"
)
study.optimize(objective, n_trials=100, timeout=600)

print("Number of finished trials: {}".format(len(study.trials)))

print("Best trial:")
trial = study.best_trial

print("  Value: {}".format(trial.value))

print("  Params: ")
for key, value in trial.params.items():
    print("    {}: {}".format(key, value))
# Out:
# [I 2023-04-28 01:46:30,659] A new study created in memory with name: no-name-422a7b6a-4312-43b5-930c-bba2a21299f0
# C:\Users\Gehan\AppData\Local\Temp\ipykernel_77100\175626622.py:30: ExperimentalWarning: CatBoostPruningCallback is experimental (supported from v3.0.0). The interface can change in the future.
#   pruning_callback = CatBoostPruningCallback(trial, "Accuracy")
# [I 2023-04-28 01:46:43,858] Trial 0 finished with value: 0.7304691674682056 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.05535531175802161, 'depth': 4, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 6.219320116085223}. Best is trial 0 with value: 0.7304691674682056.
# C:\Users\Gehan\AppData\Local\Temp\ipykernel_77100\175626622.py:30: ExperimentalWarning: CatBoostPruningCallback is experimental (supported from v3.0.0). The interface can change in the future.
#   pruning_callback = CatBoostPruningCallback(trial, "Accuracy")
# [I 2023-04-28 01:47:33,812] Trial 1 finished with value: 0.7201889020070839 and parameters: {'objective': 'CrossEntropy', 'colsample_bylevel': 0.041308592826985006, 'depth': 12, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 9.865708673256359}. Best is trial 0 with value: 0.7304691674682056.
# C:\Users\Gehan\AppData\Local\Temp\ipykernel_77100\175626622.py:30: ExperimentalWarning: CatBoostPruningCallback is experimental (supported from v3.0.0). The interface can change in the future.
#   pruning_callback = CatBoostPruningCallback(trial, "Accuracy")
# [I 2023-04-28 01:48:32,262] Trial 2 finished with value: 0.7365040009016116 and parameters: {'objective': 'CrossEntropy', 'colsample_bylevel': 0.04555911580584157, 'depth': 10, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'subsample': 0.3740569828065212}. Best is trial 2 with value: 0.7365040009016116.
# C:\Users\Gehan\AppData\Local\Temp\ipykernel_77100\175626622.py:30: ExperimentalWarning: CatBoostPruningCallback is experimental (supported from v3.0.0). The interface can change in the future.
#   pruning_callback = CatBoostPruningCallback(trial, "Accuracy")
# [I 2023-04-28 01:50:20,034] Trial 3 finished with value: 0.7453482190324295 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.0230100281470262, 'depth': 10, 'boosting_type': 'Ordered', 'bootstrap_type': 'MVS'}. Best is trial 3 with value: 0.7453482190324295.
# C:\Users\Gehan\AppData\Local\Temp\ipykernel_77100\175626622.py:30: ExperimentalWarning: CatBoostPruningCallback is experimental (supported from v3.0.0). The interface can change in the future.
#   pruning_callback = CatBoostPruningCallback(trial, "Accuracy")
# [I 2023-04-28 01:51:14,126] Trial 4 finished with value: 0.730634795354606 and parameters: {'objective': 'CrossEntropy', 'colsample_bylevel': 0.031436729225781716, 'depth': 4, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 0.7604775294303745}. Best is trial 3 with value: 0.7453482190324295.
# C:\Users\Gehan\AppData\Local\Temp\ipykernel_77100\175626622.py:30: ExperimentalWarning: CatBoostPruningCallback is experimental (supported from v3.0.0). The interface can change in the future.
#   pruning_callback = CatBoostPruningCallback(trial, "Accuracy")
# [I 2023-04-28 01:51:14,697] Trial 5 pruned. Trial was pruned at iteration 5.
# [I 2023-04-28 01:51:16,298] Trial 6 pruned. Trial was pruned at iteration 46.
# [I 2023-04-28 01:51:51,199] Trial 7 finished with value: 0.7467498150301237 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.024443441217565712, 'depth': 12, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS'}. Best is trial 7 with value: 0.7467498150301237.
# C:\Users\Gehan\AppData\Local\Temp\ipykernel_77100\175626622.py:30: ExperimentalWarning: CatBoostPruningCallback is experimental (supported from v3.0.0). The interface can change in the future.
#   pruning_callback = CatBoostPruningCallback(trial, "Accuracy")
# [I 2023-04-28 01:51:51,678] Trial 8 pruned. Trial was pruned at iteration 5.
# [I 2023-04-28 01:54:14,085] Trial 9 finished with value: 0.7353100313818851 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.05848388407918202, 'depth': 12, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 4.478229406541007}. Best is trial 7 with value: 0.7467498150301237.
# C:\Users\Gehan\AppData\Local\Temp\ipykernel_77100\175626622.py:30: ExperimentalWarning: CatBoostPruningCallback is experimental (supported from v3.0.0). The interface can change in the future.
#   pruning_callback = CatBoostPruningCallback(trial, "Accuracy")
# [I 2023-04-28 01:54:14,471] Trial 10 pruned. Trial was pruned at iteration 5.
# [I 2023-04-28 01:54:15,793] Trial 11 pruned. Trial was pruned at iteration 9.
# [I 2023-04-28 01:54:16,159] Trial 12 pruned. Trial was pruned at iteration 5.
# [I 2023-04-28 01:54:16,753] Trial 13 pruned. Trial was pruned at iteration 5.
# [I 2023-04-28 01:54:18,561] Trial 14 pruned. Trial was pruned at iteration 15.
# [I 2023-04-28 01:54:18,943] Trial 15 pruned. Trial was pruned at iteration 5.
# [I 2023-04-28 01:56:06,244] Trial 16 finished with value: 0.7440571367658032 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.03413020909815437, 'depth': 11, 'boosting_type': 'Ordered', 'bootstrap_type': 'MVS'}. Best is trial 7 with value: 0.7467498150301237.
# C:\Users\Gehan\AppData\Local\Temp\ipykernel_77100\175626622.py:30: ExperimentalWarning: CatBoostPruningCallback is experimental (supported from v3.0.0). The interface can change in the future.
#   pruning_callback = CatBoostPruningCallback(trial, "Accuracy")
# [I 2023-04-28 01:56:06,555] Trial 17 pruned. Trial was pruned at iteration 5.
# [I 2023-04-28 01:56:06,873] Trial 18 pruned. Trial was pruned at iteration 5.
# [I 2023-04-28 01:56:07,375] Trial 19 pruned. Trial was pruned at iteration 5.
# [I 2023-04-28 01:56:08,020] Trial 20 pruned. Trial was pruned at iteration 5.
# [I 2023-04-28 01:58:02,777] Trial 21 finished with value: 0.7466469532157568 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.032470178519316564, 'depth': 11, 'boosting_type': 'Ordered', 'bootstrap_type': 'MVS'}. Best is trial 7 with value: 0.7467498150301237.
# Number of finished trials: 22
# Best trial:
#   Value: 0.7467498150301237
#   Params:
#     objective: Logloss
#     colsample_bylevel: 0.024443441217565712
#     depth: 12
#     boosting_type: Plain
#     bootstrap_type: MVS

# %%
p = {'objective': 'Logloss',
 'colsample_bylevel': 0.07395734687067815,
 'depth': 11,
 'boosting_type': 'Ordered',
 'bootstrap_type': 'Bernoulli',
 'subsample': 0.712372826605781}

# %%
best_clf = CatBoostClassifier(**p)
best_clf.fit(
    X_train,
    y_train,
    eval_set=[(X_test, y_test)],
    verbose=0,
    early_stopping_rounds=100,
)
best_predictions = best_clf.predict(X_test)
pred_labels = np.rint(best_predictions)
accuracy = accuracy_score(y_test, pred_labels)
fb = fbeta_score(y_test,pred_labels,beta=0.5)

# %%
print(accuracy,fb)
# Out:
# 0.8729684908789387 0.7571473452717562

# %% [markdown]
# ### Question 5 - Final Model Evaluation
#
# * What is your optimized model's accuracy and F-score on the testing data?
# * Are these scores better or worse than the unoptimized model?
# * How do the results from your optimized model compare to the naive predictor benchmarks you found earlier in **Question 1**?_
# - **Note:** Fill in the table below with your results, and then provide discussion in the **Answer** box.

# %% [markdown]
# #### Results:
#
# |     Metric     | Unoptimized Model | Optimized Model |
# | :------------: | :---------------: | :-------------: |
# | Accuracy Score |     0.8725        |      0.8730     |
# | F-score        |     0.7554        |      0.7571     |

# %% [markdown]
# **Answer: **
# - optimizing with grid search gave worse scores but the i tried optuna which is a better hyper parameters tuning algorithm.
# - they were a lot better as expected

# %% [markdown]
# ----
# ## Feature Importance
#
# An important task when performing supervised learning on a dataset like the census data we study here is determining which features provide the most predictive power. By focusing on the relationship between only a few crucial features and the target label we simplify our understanding of the phenomenon, which is most always a useful thing to do. In the case of this project, that means we wish to identify a small number of features that most strongly predict whether an individual makes at most or more than \$50,000.
#
# Choose a scikit-learn classifier (e.g., adaboost, random forests) that has a `feature_importance_` attribute, which is a function that ranks the importance of features according to the chosen classifier.  In the next python cell fit this classifier to training set and use this attribute to determine the top 5 most important features for the census dataset.

# %% [markdown]
# ### Question 6 - Feature Relevance Observation
# When **Exploring the Data**, it was shown there are thirteen available features for each individual on record in the census data. Of these thirteen records, which five features do you believe to be most important for prediction, and in what order would you rank them and why?

# %% [markdown]
# **Answer:**
# - 1) age: because getting rich takes a long time.
# - 2) occupation: because the a person in high position is more likely to be rich than the person in low position
# - 3) education_level: because the a person with higher degree is more likely to be successful than the person with lower degree
# - 4) native_country: because some countries are richer than others and that also applies to it's citizens.
# - 5) sex: because males are more likely to be rich than females because usually males have to get more money to pay for thier families

# %% [markdown]
# ### Implementation - Extracting Feature Importance
# Choose a `scikit-learn` supervised learning algorithm that has a `feature_importance_` attribute availble for it. This attribute is a function that ranks the importance of each feature when making predictions based on the chosen algorithm.
#
# In the code cell below, you will need to implement the following:
#  - Import a supervised learning model from sklearn if it is different from the three used earlier.
#  - Train the supervised model on the entire training set.
#  - Extract the feature importances using `'.feature_importances_'`.

# %%
# TODO: Import a supervised learning model that has 'feature_importances_'

# TODO: Train the supervised model on the training set using .fit(X_train, y_train)
model = CatBoostClassifier(logging_level='Silent')
model.fit(X_train,y_train)
# TODO: Extract the feature importances using .feature_importances_ 
importances = model.feature_importances_

# Plot
vs.feature_plot(importances, X_train, y_train)

# %% [markdown]
# ### Question 7 - Extracting Feature Importance
#
# Observe the visualization created above which displays the five most relevant features for predicting if an individual makes at most or above \$50,000.
# * How do these five features compare to the five features you discussed in **Question 6**?
# * If you were close to the same answer, how does this visualization confirm your thoughts?
# * If you were not close, why do you think these features are more relevant?

# %% [markdown]
# **Answer:**
# - very different
# - it confirms my theory about the age factor.
# - becasue they ecucation number indicates ur level of education , capital gain also is a great indicator of how rich is the person.

# %% [markdown]
# ### Feature Selection
# How does a model perform if we only use a subset of all the available features in the data? With less features required to train, the expectation is that training and prediction time is much lower — at the cost of performance metrics. From the visualization above, we see that the top five most important features contribute more than half of the importance of **all** features present in the data. This hints that we can attempt to *reduce the feature space* and simplify the information required for the model to learn. The code cell below will use the same optimized model you found earlier, and train it on the same training set *with only the top five important features*.

# %%
# Import functionality for cloning a model
from sklearn.base import clone

# Reduce the feature space
X_train_reduced = X_train[X_train.columns.values[(np.argsort(importances)[::-1])[:5]]]
X_test_reduced = X_test[X_test.columns.values[(np.argsort(importances)[::-1])[:5]]]

# Train on the "best" model found from grid search earlier
clf = (clone(best_clf)).fit(X_train_reduced, y_train)

# Make new predictions
reduced_predictions = clf.predict(X_test_reduced)

# Report scores from the final model using both versions of data
print("Final Model trained on full data\n------")
print("Accuracy on testing data: {:.4f}".format(accuracy_score(y_test, best_predictions)))
print("F-score on testing data: {:.4f}".format(fbeta_score(y_test, best_predictions, beta = 0.5)))
print("\nFinal Model trained on reduced data\n------")
print("Accuracy on testing data: {:.4f}".format(accuracy_score(y_test, reduced_predictions)))
print("F-score on testing data: {:.4f}".format(fbeta_score(y_test, reduced_predictions, beta = 0.5)))
# Out:
# Learning rate set to 0.047685
# 0:	learn: 0.6802645	total: 45.5ms	remaining: 45.4s
# 1:	learn: 0.6686405	total: 84.2ms	remaining: 42s
# 2:	learn: 0.6581542	total: 132ms	remaining: 44s
# 3:	learn: 0.6421518	total: 178ms	remaining: 44.4s
# 4:	learn: 0.6336150	total: 246ms	remaining: 49s
# 5:	learn: 0.6259157	total: 293ms	remaining: 48.6s
# 6:	learn: 0.6189717	total: 355ms	remaining: 50.4s
# 7:	learn: 0.5960103	total: 438ms	remaining: 54.3s
# 8:	learn: 0.5787374	total: 506ms	remaining: 55.7s
# 9:	learn: 0.5686818	total: 556ms	remaining: 55s
# 10:	learn: 0.5555372	total: 609ms	remaining: 54.7s
# 11:	learn: 0.5518640	total: 648ms	remaining: 53.4s
# 12:	learn: 0.5485493	total: 693ms	remaining: 52.6s
# 13:	learn: 0.5455576	total: 738ms	remaining: 52s
# 14:	learn: 0.5375539	total: 782ms	remaining: 51.4s
# 15:	learn: 0.5350713	total: 816ms	remaining: 50.2s
# 16:	learn: 0.5328298	total: 852ms	remaining: 49.3s
# 17:	learn: 0.5308057	total: 885ms	remaining: 48.3s
# 18:	learn: 0.5181934	total: 922ms	remaining: 47.6s
# 19:	learn: 0.5166567	total: 958ms	remaining: 47s
# 20:	learn: 0.5152684	total: 993ms	remaining: 46.3s
# 21:	learn: 0.5140139	total: 1.03s	remaining: 45.8s
# 22:	learn: 0.5082582	total: 1.07s	remaining: 45.5s
# 23:	learn: 0.5072860	total: 1.11s	remaining: 45.1s
# 24:	learn: 0.5064070	total: 1.15s	remaining: 44.7s
# 25:	learn: 0.5010338	total: 1.19s	remaining: 44.6s
# 26:	learn: 0.4977389	total: 1.25s	remaining: 44.9s
# 27:	learn: 0.4970585	total: 1.28s	remaining: 44.6s
# 28:	learn: 0.4964432	total: 1.32s	remaining: 44.3s
# 29:	learn: 0.4958867	total: 1.39s	remaining: 45s
# 30:	learn: 0.4877453	total: 1.47s	remaining: 45.9s
# 31:	learn: 0.4873386	total: 1.53s	remaining: 46.2s
# 32:	learn: 0.4869705	total: 1.57s	remaining: 46.1s
# 33:	learn: 0.4866374	total: 1.61s	remaining: 45.7s
# 34:	learn: 0.4863360	total: 1.65s	remaining: 45.6s
# 35:	learn: 0.4860631	total: 1.7s	remaining: 45.6s
# 36:	learn: 0.4858161	total: 1.76s	remaining: 45.7s
# 37:	learn: 0.4827741	total: 1.8s	remaining: 45.7s
# 38:	learn: 0.4825640	total: 1.84s	remaining: 45.4s
# 39:	learn: 0.4823739	total: 1.89s	remaining: 45.4s
# 40:	learn: 0.4822016	total: 1.96s	remaining: 45.8s
# 41:	learn: 0.4820457	total: 2.01s	remaining: 45.8s
# 42:	learn: 0.4819045	total: 2.06s	remaining: 46s
# 43:	learn: 0.4783610	total: 2.11s	remaining: 45.8s
# 44:	learn: 0.4719337	total: 2.15s	remaining: 45.7s
# 45:	learn: 0.4718297	total: 2.21s	remaining: 45.8s
# 46:	learn: 0.4653060	total: 2.25s	remaining: 45.6s
# 47:	learn: 0.4652381	total: 2.29s	remaining: 45.4s
# 48:	learn: 0.4651765	total: 2.35s	remaining: 45.5s
# 49:	learn: 0.4617499	total: 2.41s	remaining: 45.8s
# 50:	learn: 0.4590226	total: 2.48s	remaining: 46.1s
# 51:	learn: 0.4589881	total: 2.58s	remaining: 47s
# 52:	learn: 0.4589567	total: 2.67s	remaining: 47.6s
# 53:	learn: 0.4589283	total: 2.75s	remaining: 48.2s
# 54:	learn: 0.4589026	total: 2.8s	remaining: 48.2s
# 55:	learn: 0.4588793	total: 2.85s	remaining: 48s
# 56:	learn: 0.4564266	total: 2.9s	remaining: 48s
# 57:	learn: 0.4564093	total: 2.96s	remaining: 48.2s
# 58:	learn: 0.4539153	total: 3.03s	remaining: 48.4s
# 59:	learn: 0.4498562	total: 3.08s	remaining: 48.3s
# 60:	learn: 0.4498500	total: 3.13s	remaining: 48.3s
# 61:	learn: 0.4498444	total: 3.18s	remaining: 48.2s
# 62:	learn: 0.4498394	total: 3.24s	remaining: 48.1s
# 63:	learn: 0.4459713	total: 3.33s	remaining: 48.8s
# 64:	learn: 0.4459670	total: 3.38s	remaining: 48.7s
# 65:	learn: 0.4442865	total: 3.43s	remaining: 48.6s
# 66:	learn: 0.4423487	total: 3.48s	remaining: 48.4s
# 67:	learn: 0.4335794	total: 3.52s	remaining: 48.2s
# 68:	learn: 0.4335794	total: 3.58s	remaining: 48.3s
# 69:	learn: 0.4335794	total: 3.62s	remaining: 48.1s
# 70:	learn: 0.4298109	total: 3.67s	remaining: 48.1s
# 71:	learn: 0.4275617	total: 3.73s	remaining: 48s
# 72:	learn: 0.4275617	total: 3.77s	remaining: 47.9s
# 73:	learn: 0.4267350	total: 3.83s	remaining: 47.9s
# 74:	learn: 0.4248148	total: 3.88s	remaining: 47.8s
# 75:	learn: 0.4240585	total: 3.92s	remaining: 47.7s
# 76:	learn: 0.4240584	total: 3.97s	remaining: 47.6s
# 77:	learn: 0.4240583	total: 4.01s	remaining: 47.4s
# 78:	learn: 0.4240582	total: 4.05s	remaining: 47.2s
# 79:	learn: 0.4240581	total: 4.09s	remaining: 47.1s
# 80:	learn: 0.4240581	total: 4.13s	remaining: 46.9s
# 81:	learn: 0.4233695	total: 4.17s	remaining: 46.7s
# 82:	learn: 0.4180719	total: 4.23s	remaining: 46.7s
# 83:	learn: 0.4180714	total: 4.27s	remaining: 46.6s
# 84:	learn: 0.4136799	total: 4.33s	remaining: 46.6s
# 85:	learn: 0.4095993	total: 4.38s	remaining: 46.5s
# 86:	learn: 0.4095967	total: 4.42s	remaining: 46.3s
# 87:	learn: 0.4084302	total: 4.46s	remaining: 46.3s
# 88:	learn: 0.4079589	total: 4.54s	remaining: 46.4s
# 89:	learn: 0.4049840	total: 4.6s	remaining: 46.5s
# 90:	learn: 0.4037984	total: 4.65s	remaining: 46.4s
# 91:	learn: 0.4037945	total: 4.7s	remaining: 46.4s
# 92:	learn: 0.4037910	total: 4.74s	remaining: 46.2s
# 93:	learn: 0.4027978	total: 4.8s	remaining: 46.2s
# 94:	learn: 0.4017267	total: 4.84s	remaining: 46.1s
# 95:	learn: 0.4007547	total: 4.88s	remaining: 46s
# 96:	learn: 0.3998301	total: 4.93s	remaining: 45.9s
# 97:	learn: 0.3998268	total: 4.97s	remaining: 45.7s
# 98:	learn: 0.3998238	total: 5s	remaining: 45.5s
# 99:	learn: 0.3998211	total: 5.05s	remaining: 45.5s
# 100:	learn: 0.3998186	total: 5.09s	remaining: 45.4s
# 101:	learn: 0.3998164	total: 5.13s	remaining: 45.2s
# 102:	learn: 0.3994104	total: 5.18s	remaining: 45.1s
# 103:	learn: 0.3982504	total: 5.25s	remaining: 45.2s
# 104:	learn: 0.3982481	total: 5.29s	remaining: 45.1s
# 105:	learn: 0.3982460	total: 5.33s	remaining: 44.9s
# 106:	learn: 0.3982441	total: 5.37s	remaining: 44.9s
# 107:	learn: 0.3956555	total: 5.42s	remaining: 44.8s
# 108:	learn: 0.3956527	total: 5.47s	remaining: 44.7s
# 109:	learn: 0.3918056	total: 5.52s	remaining: 44.7s
# 110:	learn: 0.3901500	total: 5.58s	remaining: 44.7s
# 111:	learn: 0.3901465	total: 5.63s	remaining: 44.6s
# 112:	learn: 0.3901433	total: 5.72s	remaining: 44.9s
# 113:	learn: 0.3901404	total: 5.77s	remaining: 44.9s
# 114:	learn: 0.3901378	total: 5.82s	remaining: 44.8s
# 115:	learn: 0.3880852	total: 5.89s	remaining: 44.9s
# 116:	learn: 0.3880820	total: 5.93s	remaining: 44.8s
# 117:	learn: 0.3880791	total: 5.98s	remaining: 44.7s
# 118:	learn: 0.3880765	total: 6.03s	remaining: 44.6s
# 119:	learn: 0.3880741	total: 6.12s	remaining: 44.9s
# 120:	learn: 0.3871003	total: 6.17s	remaining: 44.8s
# 121:	learn: 0.3870988	total: 6.23s	remaining: 44.8s
# 122:	learn: 0.3870974	total: 6.28s	remaining: 44.8s
# 123:	learn: 0.3870961	total: 6.33s	remaining: 44.7s
# 124:	learn: 0.3870950	total: 6.37s	remaining: 44.6s
# 125:	learn: 0.3870939	total: 6.4s	remaining: 44.4s
# 126:	learn: 0.3870930	total: 6.44s	remaining: 44.3s
# 127:	learn: 0.3860816	total: 6.49s	remaining: 44.2s
# 128:	learn: 0.3860804	total: 6.53s	remaining: 44.1s
# 129:	learn: 0.3860792	total: 6.58s	remaining: 44s
# 130:	learn: 0.3860782	total: 6.62s	remaining: 43.9s
# 131:	learn: 0.3860773	total: 6.66s	remaining: 43.8s
# 132:	learn: 0.3844997	total: 6.72s	remaining: 43.8s
# 133:	learn: 0.3844991	total: 6.76s	remaining: 43.7s
# 134:	learn: 0.3844985	total: 6.81s	remaining: 43.6s
# 135:	learn: 0.3844980	total: 6.85s	remaining: 43.5s
# 136:	learn: 0.3844975	total: 6.89s	remaining: 43.4s
# 137:	learn: 0.3844971	total: 6.93s	remaining: 43.3s
# 138:	learn: 0.3844967	total: 6.96s	remaining: 43.1s
# 139:	learn: 0.3844963	total: 7.01s	remaining: 43.1s
# 140:	learn: 0.3844963	total: 7.05s	remaining: 43s
# 141:	learn: 0.3844960	total: 7.09s	remaining: 42.8s
# 142:	learn: 0.3844957	total: 7.14s	remaining: 42.8s
# 143:	learn: 0.3826749	total: 7.19s	remaining: 42.7s
# 144:	learn: 0.3826743	total: 7.23s	remaining: 42.6s
# 145:	learn: 0.3826737	total: 7.27s	remaining: 42.5s
# 146:	learn: 0.3826732	total: 7.31s	remaining: 42.4s
# 147:	learn: 0.3826728	total: 7.35s	remaining: 42.3s
# 148:	learn: 0.3826724	total: 7.39s	remaining: 42.2s
# 149:	learn: 0.3821009	total: 7.43s	remaining: 42.1s
# 150:	learn: 0.3821005	total: 7.48s	remaining: 42.1s
# 151:	learn: 0.3821002	total: 7.52s	remaining: 42s
# 152:	learn: 0.3820999	total: 7.56s	remaining: 41.9s
# 153:	learn: 0.3812786	total: 7.61s	remaining: 41.8s
# 154:	learn: 0.3812782	total: 7.65s	remaining: 41.7s
# 155:	learn: 0.3796701	total: 7.72s	remaining: 41.7s
# 156:	learn: 0.3796694	total: 7.76s	remaining: 41.7s
# 157:	learn: 0.3769850	total: 7.81s	remaining: 41.6s
# 158:	learn: 0.3769837	total: 7.84s	remaining: 41.5s
# 159:	learn: 0.3756959	total: 7.9s	remaining: 41.5s
# 160:	learn: 0.3749598	total: 7.94s	remaining: 41.4s
# 161:	learn: 0.3749580	total: 7.98s	remaining: 41.3s
# 162:	learn: 0.3746427	total: 8.03s	remaining: 41.2s
# 163:	learn: 0.3740469	total: 8.08s	remaining: 41.2s
# 164:	learn: 0.3733640	total: 8.15s	remaining: 41.2s
# 165:	learn: 0.3733629	total: 8.22s	remaining: 41.3s
# 166:	learn: 0.3733620	total: 8.27s	remaining: 41.3s
# 167:	learn: 0.3733611	total: 8.31s	remaining: 41.2s
# 168:	learn: 0.3727987	total: 8.36s	remaining: 41.1s
# 169:	learn: 0.3727979	total: 8.4s	remaining: 41s
# 170:	learn: 0.3727972	total: 8.44s	remaining: 40.9s
# 171:	learn: 0.3727966	total: 8.48s	remaining: 40.8s
# 172:	learn: 0.3722868	total: 8.52s	remaining: 40.7s
# 173:	learn: 0.3713102	total: 8.75s	remaining: 41.5s
# 174:	learn: 0.3701513	total: 8.86s	remaining: 41.8s
# 175:	learn: 0.3691087	total: 8.98s	remaining: 42s
# 176:	learn: 0.3688247	total: 9.03s	remaining: 42s
# 177:	learn: 0.3683883	total: 9.09s	remaining: 42s
# 178:	learn: 0.3674601	total: 9.14s	remaining: 41.9s
# 179:	learn: 0.3674593	total: 9.21s	remaining: 42s
# 180:	learn: 0.3674586	total: 9.28s	remaining: 42s
# 181:	learn: 0.3668865	total: 9.33s	remaining: 41.9s
# 182:	learn: 0.3668860	total: 9.38s	remaining: 41.9s
# 183:	learn: 0.3668856	total: 9.41s	remaining: 41.8s
# 184:	learn: 0.3668853	total: 9.46s	remaining: 41.7s
# 185:	learn: 0.3668849	total: 9.51s	remaining: 41.6s
# 186:	learn: 0.3663796	total: 9.56s	remaining: 41.6s
# 187:	learn: 0.3663794	total: 9.61s	remaining: 41.5s
# 188:	learn: 0.3663792	total: 9.7s	remaining: 41.6s
# 189:	learn: 0.3663791	total: 9.76s	remaining: 41.6s
# 190:	learn: 0.3663790	total: 9.81s	remaining: 41.5s
# 191:	learn: 0.3663789	total: 9.85s	remaining: 41.5s
# 192:	learn: 0.3663788	total: 9.89s	remaining: 41.4s
# 193:	learn: 0.3663787	total: 9.94s	remaining: 41.3s
# 194:	learn: 0.3663786	total: 9.98s	remaining: 41.2s
# 195:	learn: 0.3663786	total: 10s	remaining: 41.1s
# 196:	learn: 0.3643371	total: 10.1s	remaining: 41.1s
# 197:	learn: 0.3643370	total: 10.1s	remaining: 41s
# 198:	learn: 0.3635804	total: 10.2s	remaining: 41s
# 199:	learn: 0.3635801	total: 10.3s	remaining: 41.2s
# 200:	learn: 0.3635799	total: 10.3s	remaining: 41.1s
# 201:	learn: 0.3635799	total: 10.4s	remaining: 41s
# 202:	learn: 0.3635797	total: 10.4s	remaining: 41s
# 203:	learn: 0.3631946	total: 10.5s	remaining: 41s
# 204:	learn: 0.3631945	total: 10.6s	remaining: 40.9s
# 205:	learn: 0.3631944	total: 10.6s	remaining: 40.8s
# 206:	learn: 0.3631943	total: 10.6s	remaining: 40.8s
# 207:	learn: 0.3631942	total: 10.7s	remaining: 40.8s
# 208:	learn: 0.3631941	total: 10.8s	remaining: 40.7s
# 209:	learn: 0.3629318	total: 10.8s	remaining: 40.7s
# 210:	learn: 0.3629318	total: 10.9s	remaining: 40.6s
# 211:	learn: 0.3629318	total: 11s	remaining: 40.7s
# 212:	learn: 0.3629317	total: 11s	remaining: 40.8s
# 213:	learn: 0.3629317	total: 11.1s	remaining: 40.7s
# 214:	learn: 0.3629316	total: 11.2s	remaining: 40.8s
# 215:	learn: 0.3629316	total: 11.2s	remaining: 40.8s
# 216:	learn: 0.3624690	total: 11.3s	remaining: 40.9s
# 217:	learn: 0.3617802	total: 11.4s	remaining: 40.8s
# 218:	learn: 0.3605777	total: 11.5s	remaining: 40.9s
# 219:	learn: 0.3595061	total: 11.5s	remaining: 40.8s
# 220:	learn: 0.3595056	total: 11.5s	remaining: 40.7s
# 221:	learn: 0.3595051	total: 11.6s	remaining: 40.6s
# 222:	learn: 0.3595047	total: 11.7s	remaining: 40.6s
# 223:	learn: 0.3595043	total: 11.7s	remaining: 40.6s
# 224:	learn: 0.3595040	total: 11.8s	remaining: 40.6s
# 225:	learn: 0.3586731	total: 11.8s	remaining: 40.5s
# 226:	learn: 0.3586726	total: 11.9s	remaining: 40.6s
# 227:	learn: 0.3586721	total: 12s	remaining: 40.6s
# 228:	learn: 0.3586717	total: 12.1s	remaining: 40.6s
# 229:	learn: 0.3586713	total: 12.1s	remaining: 40.6s
# 230:	learn: 0.3579155	total: 12.2s	remaining: 40.6s
# 231:	learn: 0.3579150	total: 12.3s	remaining: 40.6s
# 232:	learn: 0.3579145	total: 12.3s	remaining: 40.5s
# 233:	learn: 0.3579141	total: 12.4s	remaining: 40.4s
# 234:	learn: 0.3575506	total: 12.4s	remaining: 40.4s
# 235:	learn: 0.3575503	total: 12.5s	remaining: 40.3s
# 236:	learn: 0.3575500	total: 12.5s	remaining: 40.3s
# 237:	learn: 0.3564234	total: 12.6s	remaining: 40.2s
# 238:	learn: 0.3564229	total: 12.6s	remaining: 40.2s
# 239:	learn: 0.3559117	total: 12.7s	remaining: 40.2s
# 240:	learn: 0.3559115	total: 12.7s	remaining: 40.1s
# 241:	learn: 0.3550956	total: 12.8s	remaining: 40.1s
# 242:	learn: 0.3549388	total: 12.8s	remaining: 40s
# 243:	learn: 0.3549388	total: 12.9s	remaining: 40s
# 244:	learn: 0.3543898	total: 13s	remaining: 39.9s
# 245:	learn: 0.3543897	total: 13s	remaining: 39.9s
# 246:	learn: 0.3541634	total: 13.1s	remaining: 39.9s
# 247:	learn: 0.3541633	total: 13.2s	remaining: 40s
# 248:	learn: 0.3541633	total: 13.2s	remaining: 40s
# 249:	learn: 0.3541632	total: 13.3s	remaining: 39.9s
# 250:	learn: 0.3541631	total: 13.3s	remaining: 39.8s
# 251:	learn: 0.3541631	total: 13.4s	remaining: 39.7s
# 252:	learn: 0.3541631	total: 13.4s	remaining: 39.6s
# 253:	learn: 0.3541631	total: 13.5s	remaining: 39.5s
# 254:	learn: 0.3525740	total: 13.5s	remaining: 39.5s
# 255:	learn: 0.3525738	total: 13.6s	remaining: 39.4s
# 256:	learn: 0.3521350	total: 13.6s	remaining: 39.4s
# 257:	learn: 0.3517379	total: 13.7s	remaining: 39.3s
# 258:	learn: 0.3517376	total: 13.7s	remaining: 39.2s
# 259:	learn: 0.3517374	total: 13.7s	remaining: 39.1s
# 260:	learn: 0.3510174	total: 13.8s	remaining: 39.1s
# 261:	learn: 0.3506533	total: 13.9s	remaining: 39s
# 262:	learn: 0.3502416	total: 13.9s	remaining: 38.9s
# 263:	learn: 0.3502412	total: 13.9s	remaining: 38.9s
# 264:	learn: 0.3499022	total: 14s	remaining: 38.8s
# 265:	learn: 0.3499020	total: 14s	remaining: 38.8s
# 266:	learn: 0.3499018	total: 14.1s	remaining: 38.7s
# 267:	learn: 0.3499016	total: 14.1s	remaining: 38.6s
# 268:	learn: 0.3499015	total: 14.2s	remaining: 38.5s
# 269:	learn: 0.3497746	total: 14.2s	remaining: 38.5s
# 270:	learn: 0.3492561	total: 14.3s	remaining: 38.4s
# 271:	learn: 0.3492559	total: 14.4s	remaining: 38.5s
# 272:	learn: 0.3492558	total: 14.5s	remaining: 38.5s
# 273:	learn: 0.3492556	total: 14.5s	remaining: 38.5s
# 274:	learn: 0.3492556	total: 14.6s	remaining: 38.5s
# 275:	learn: 0.3492556	total: 14.7s	remaining: 38.6s
# 276:	learn: 0.3489822	total: 14.8s	remaining: 38.5s
# 277:	learn: 0.3485091	total: 14.8s	remaining: 38.5s
# 278:	learn: 0.3485090	total: 14.9s	remaining: 38.5s
# 279:	learn: 0.3485089	total: 15s	remaining: 38.5s
# 280:	learn: 0.3485089	total: 15s	remaining: 38.4s
# 281:	learn: 0.3485089	total: 15.1s	remaining: 38.3s
# 282:	learn: 0.3485089	total: 15.1s	remaining: 38.2s
# 283:	learn: 0.3485089	total: 15.1s	remaining: 38.2s
# 284:	learn: 0.3481963	total: 15.2s	remaining: 38.1s
# 285:	learn: 0.3481962	total: 15.2s	remaining: 38.1s
# 286:	learn: 0.3481961	total: 15.3s	remaining: 38s
# 287:	learn: 0.3481961	total: 15.3s	remaining: 37.9s
# 288:	learn: 0.3481960	total: 15.4s	remaining: 37.8s
# 289:	learn: 0.3481960	total: 15.4s	remaining: 37.8s
# 290:	learn: 0.3481959	total: 15.5s	remaining: 37.7s
# 291:	learn: 0.3476692	total: 15.6s	remaining: 37.7s
# 292:	learn: 0.3476692	total: 15.6s	remaining: 37.7s
# 293:	learn: 0.3476691	total: 15.7s	remaining: 37.7s
# 294:	learn: 0.3476691	total: 15.7s	remaining: 37.6s
# 295:	learn: 0.3474112	total: 15.8s	remaining: 37.6s
# 296:	learn: 0.3474111	total: 15.8s	remaining: 37.5s
# 297:	learn: 0.3474111	total: 15.9s	remaining: 37.4s
# 298:	learn: 0.3474111	total: 15.9s	remaining: 37.3s
# 299:	learn: 0.3474111	total: 16s	remaining: 37.3s
# 300:	learn: 0.3464305	total: 16.1s	remaining: 37.3s
# 301:	learn: 0.3457359	total: 16.2s	remaining: 37.4s
# 302:	learn: 0.3457358	total: 16.3s	remaining: 37.4s
# 303:	learn: 0.3457356	total: 16.3s	remaining: 37.4s
# 304:	learn: 0.3457356	total: 16.4s	remaining: 37.3s
# 305:	learn: 0.3457356	total: 16.4s	remaining: 37.2s
# 306:	learn: 0.3455284	total: 16.5s	remaining: 37.3s
# 307:	learn: 0.3455282	total: 16.6s	remaining: 37.3s
# 308:	learn: 0.3453409	total: 16.7s	remaining: 37.3s
# 309:	learn: 0.3453407	total: 16.7s	remaining: 37.3s
# 310:	learn: 0.3451003	total: 16.8s	remaining: 37.2s
# 311:	learn: 0.3451001	total: 16.8s	remaining: 37.1s
# 312:	learn: 0.3451001	total: 16.9s	remaining: 37.1s
# 313:	learn: 0.3450999	total: 17s	remaining: 37.1s
# 314:	learn: 0.3449905	total: 17s	remaining: 37s
# 315:	learn: 0.3449903	total: 17.1s	remaining: 37s
# 316:	learn: 0.3449902	total: 17.1s	remaining: 36.9s
# 317:	learn: 0.3449902	total: 17.2s	remaining: 36.9s
# 318:	learn: 0.3449901	total: 17.3s	remaining: 36.8s
# 319:	learn: 0.3443245	total: 17.3s	remaining: 36.8s
# 320:	learn: 0.3443244	total: 17.4s	remaining: 36.7s
# 321:	learn: 0.3441294	total: 17.5s	remaining: 36.8s
# 322:	learn: 0.3440455	total: 17.6s	remaining: 36.8s
# 323:	learn: 0.3438893	total: 17.7s	remaining: 37s
# 324:	learn: 0.3438892	total: 17.8s	remaining: 37s
# 325:	learn: 0.3438891	total: 17.9s	remaining: 37s
# 326:	learn: 0.3438891	total: 17.9s	remaining: 36.9s
# 327:	learn: 0.3438891	total: 18s	remaining: 36.9s
# 328:	learn: 0.3438891	total: 18.1s	remaining: 36.9s
# 329:	learn: 0.3438891	total: 18.1s	remaining: 36.8s
# 330:	learn: 0.3438891	total: 18.2s	remaining: 36.8s
# 331:	learn: 0.3438891	total: 18.2s	remaining: 36.7s
# 332:	learn: 0.3436721	total: 18.3s	remaining: 36.6s
# 333:	learn: 0.3436720	total: 18.3s	remaining: 36.5s
# 334:	learn: 0.3436720	total: 18.4s	remaining: 36.5s
# 335:	learn: 0.3436720	total: 18.4s	remaining: 36.4s
# 336:	learn: 0.3436719	total: 18.5s	remaining: 36.3s
# 337:	learn: 0.3436719	total: 18.6s	remaining: 36.3s
# 338:	learn: 0.3436719	total: 18.6s	remaining: 36.3s
# 339:	learn: 0.3434965	total: 18.7s	remaining: 36.3s
# 340:	learn: 0.3434965	total: 18.7s	remaining: 36.2s
# 341:	learn: 0.3434965	total: 18.8s	remaining: 36.2s
# 342:	learn: 0.3433007	total: 18.9s	remaining: 36.1s
# 343:	learn: 0.3433007	total: 18.9s	remaining: 36s
# 344:	learn: 0.3433007	total: 19s	remaining: 36s
# 345:	learn: 0.3433007	total: 19s	remaining: 35.9s
# 346:	learn: 0.3433006	total: 19s	remaining: 35.8s
# 347:	learn: 0.3431579	total: 19.1s	remaining: 35.7s
# 348:	learn: 0.3430560	total: 19.1s	remaining: 35.7s
# 349:	learn: 0.3430560	total: 19.2s	remaining: 35.6s
# 350:	learn: 0.3428272	total: 19.2s	remaining: 35.6s
# 351:	learn: 0.3428272	total: 19.3s	remaining: 35.5s
# 352:	learn: 0.3428272	total: 19.3s	remaining: 35.4s
# 353:	learn: 0.3424514	total: 19.4s	remaining: 35.3s
# 354:	learn: 0.3424514	total: 19.4s	remaining: 35.3s
# 355:	learn: 0.3424514	total: 19.5s	remaining: 35.2s
# 356:	learn: 0.3424514	total: 19.5s	remaining: 35.1s
# 357:	learn: 0.3424514	total: 19.5s	remaining: 35s
# 358:	learn: 0.3424514	total: 19.6s	remaining: 35s
# 359:	learn: 0.3424514	total: 19.6s	remaining: 34.9s
# 360:	learn: 0.3423684	total: 19.7s	remaining: 34.9s
# 361:	learn: 0.3420022	total: 19.8s	remaining: 34.8s
# 362:	learn: 0.3420022	total: 19.8s	remaining: 34.7s
# 363:	learn: 0.3418920	total: 19.8s	remaining: 34.7s
# 364:	learn: 0.3418920	total: 19.9s	remaining: 34.6s
# 365:	learn: 0.3418920	total: 19.9s	remaining: 34.6s
# 366:	learn: 0.3418920	total: 20s	remaining: 34.5s
# 367:	learn: 0.3418920	total: 20s	remaining: 34.4s
# 368:	learn: 0.3418920	total: 20.1s	remaining: 34.3s
# 369:	learn: 0.3418920	total: 20.1s	remaining: 34.3s
# 370:	learn: 0.3416828	total: 20.2s	remaining: 34.2s
# 371:	learn: 0.3416828	total: 20.2s	remaining: 34.1s
# 372:	learn: 0.3416828	total: 20.3s	remaining: 34.1s
# 373:	learn: 0.3416828	total: 20.3s	remaining: 34s
# 374:	learn: 0.3407176	total: 20.4s	remaining: 34s
# 375:	learn: 0.3407176	total: 20.5s	remaining: 34s
# 376:	learn: 0.3398600	total: 20.5s	remaining: 33.9s
# 377:	learn: 0.3398600	total: 20.6s	remaining: 33.9s
# 378:	learn: 0.3384110	total: 20.7s	remaining: 33.9s
# 379:	learn: 0.3384110	total: 20.7s	remaining: 33.8s
# 380:	learn: 0.3384109	total: 20.8s	remaining: 33.7s
# 381:	learn: 0.3382575	total: 20.8s	remaining: 33.7s
# 382:	learn: 0.3382575	total: 20.9s	remaining: 33.6s
# 383:	learn: 0.3382575	total: 20.9s	remaining: 33.6s
# 384:	learn: 0.3380334	total: 21s	remaining: 33.6s
# 385:	learn: 0.3379509	total: 21.1s	remaining: 33.5s
# 386:	learn: 0.3377316	total: 21.2s	remaining: 33.5s
# 387:	learn: 0.3376861	total: 21.3s	remaining: 33.5s
# 388:	learn: 0.3376861	total: 21.3s	remaining: 33.5s
# 389:	learn: 0.3376861	total: 21.4s	remaining: 33.5s
# 390:	learn: 0.3376152	total: 21.5s	remaining: 33.4s
# 391:	learn: 0.3376152	total: 21.5s	remaining: 33.4s
# 392:	learn: 0.3376152	total: 21.6s	remaining: 33.4s
# 393:	learn: 0.3376152	total: 21.7s	remaining: 33.3s
# 394:	learn: 0.3375127	total: 21.7s	remaining: 33.3s
# 395:	learn: 0.3375127	total: 21.8s	remaining: 33.2s
# 396:	learn: 0.3375127	total: 21.8s	remaining: 33.2s
# 397:	learn: 0.3375127	total: 21.9s	remaining: 33.1s
# 398:	learn: 0.3375127	total: 21.9s	remaining: 33.1s
# 399:	learn: 0.3373452	total: 22s	remaining: 33s
# 400:	learn: 0.3373452	total: 22.1s	remaining: 33s
# 401:	learn: 0.3373452	total: 22.2s	remaining: 33s
# 402:	learn: 0.3372728	total: 22.2s	remaining: 32.9s
# 403:	learn: 0.3369519	total: 22.3s	remaining: 32.9s
# 404:	learn: 0.3368879	total: 22.3s	remaining: 32.8s
# 405:	learn: 0.3368879	total: 22.4s	remaining: 32.7s
# 406:	learn: 0.3368879	total: 22.4s	remaining: 32.7s
# 407:	learn: 0.3368879	total: 22.5s	remaining: 32.6s
# 408:	learn: 0.3367503	total: 22.5s	remaining: 32.6s
# 409:	learn: 0.3367503	total: 22.6s	remaining: 32.5s
# 410:	learn: 0.3367503	total: 22.6s	remaining: 32.4s
# 411:	learn: 0.3367503	total: 22.7s	remaining: 32.4s
# 412:	learn: 0.3367503	total: 22.8s	remaining: 32.4s
# 413:	learn: 0.3366256	total: 22.8s	remaining: 32.3s
# 414:	learn: 0.3366256	total: 22.9s	remaining: 32.2s
# 415:	learn: 0.3364035	total: 22.9s	remaining: 32.2s
# 416:	learn: 0.3364035	total: 23s	remaining: 32.1s
# 417:	learn: 0.3362117	total: 23.1s	remaining: 32.1s
# 418:	learn: 0.3362117	total: 23.1s	remaining: 32.1s
# 419:	learn: 0.3360868	total: 23.2s	remaining: 32.1s
# 420:	learn: 0.3355381	total: 23.3s	remaining: 32s
# 421:	learn: 0.3354351	total: 23.3s	remaining: 31.9s
# 422:	learn: 0.3354351	total: 23.4s	remaining: 31.9s
# 423:	learn: 0.3354351	total: 23.4s	remaining: 31.8s
# 424:	learn: 0.3354351	total: 23.5s	remaining: 31.8s
# 425:	learn: 0.3354351	total: 23.5s	remaining: 31.7s
# 426:	learn: 0.3354351	total: 23.6s	remaining: 31.7s
# 427:	learn: 0.3353075	total: 23.7s	remaining: 31.6s
# 428:	learn: 0.3353075	total: 23.7s	remaining: 31.6s
# 429:	learn: 0.3353075	total: 23.8s	remaining: 31.5s
# 430:	learn: 0.3353075	total: 23.8s	remaining: 31.5s
# 431:	learn: 0.3351922	total: 23.9s	remaining: 31.5s
# 432:	learn: 0.3351922	total: 24s	remaining: 31.4s
# 433:	learn: 0.3350386	total: 24s	remaining: 31.3s
# 434:	learn: 0.3349706	total: 24.1s	remaining: 31.3s
# 435:	learn: 0.3349706	total: 24.1s	remaining: 31.2s
# 436:	learn: 0.3349706	total: 24.2s	remaining: 31.2s
# 437:	learn: 0.3349706	total: 24.2s	remaining: 31.1s
# 438:	learn: 0.3349706	total: 24.3s	remaining: 31s
# 439:	learn: 0.3348741	total: 24.3s	remaining: 31s
# 440:	learn: 0.3347996	total: 24.4s	remaining: 31s
# 441:	learn: 0.3347996	total: 24.5s	remaining: 30.9s
# 442:	learn: 0.3347996	total: 24.6s	remaining: 30.9s
# 443:	learn: 0.3347504	total: 24.6s	remaining: 30.8s
# 444:	learn: 0.3347504	total: 24.7s	remaining: 30.8s
# 445:	learn: 0.3347504	total: 24.7s	remaining: 30.7s
# 446:	learn: 0.3347504	total: 24.8s	remaining: 30.6s
# 447:	learn: 0.3347504	total: 24.8s	remaining: 30.6s
# 448:	learn: 0.3347340	total: 24.9s	remaining: 30.6s
# 449:	learn: 0.3347340	total: 25.1s	remaining: 30.7s
# 450:	learn: 0.3346456	total: 25.2s	remaining: 30.7s
# 451:	learn: 0.3344961	total: 25.3s	remaining: 30.7s
# 452:	learn: 0.3344961	total: 25.4s	remaining: 30.7s
# 453:	learn: 0.3344961	total: 25.4s	remaining: 30.6s
# 454:	learn: 0.3344961	total: 25.5s	remaining: 30.5s
# 455:	learn: 0.3344961	total: 25.5s	remaining: 30.5s
# 456:	learn: 0.3344961	total: 25.6s	remaining: 30.4s
# 457:	learn: 0.3344961	total: 25.7s	remaining: 30.4s
# 458:	learn: 0.3344395	total: 25.8s	remaining: 30.4s
# 459:	learn: 0.3343093	total: 25.9s	remaining: 30.3s
# 460:	learn: 0.3343093	total: 25.9s	remaining: 30.3s
# 461:	learn: 0.3342585	total: 26s	remaining: 30.3s
# 462:	learn: 0.3339815	total: 26.2s	remaining: 30.3s
# 463:	learn: 0.3339815	total: 26.2s	remaining: 30.3s
# 464:	learn: 0.3339815	total: 26.3s	remaining: 30.2s
# 465:	learn: 0.3339815	total: 26.3s	remaining: 30.2s
# 466:	learn: 0.3339815	total: 26.4s	remaining: 30.1s
# 467:	learn: 0.3339346	total: 26.4s	remaining: 30s
# 468:	learn: 0.3338784	total: 26.5s	remaining: 30s
# 469:	learn: 0.3338784	total: 26.5s	remaining: 29.9s
# 470:	learn: 0.3338784	total: 26.6s	remaining: 29.9s
# 471:	learn: 0.3338384	total: 26.6s	remaining: 29.8s
# 472:	learn: 0.3338384	total: 26.7s	remaining: 29.8s
# 473:	learn: 0.3338384	total: 26.8s	remaining: 29.7s
# 474:	learn: 0.3337453	total: 26.9s	remaining: 29.7s
# 475:	learn: 0.3335191	total: 26.9s	remaining: 29.7s
# 476:	learn: 0.3335191	total: 27s	remaining: 29.6s
# 477:	learn: 0.3335191	total: 27s	remaining: 29.5s
# 478:	learn: 0.3335191	total: 27.1s	remaining: 29.5s
# 479:	learn: 0.3335191	total: 27.2s	remaining: 29.4s
# 480:	learn: 0.3332183	total: 27.2s	remaining: 29.4s
# 481:	learn: 0.3332183	total: 27.3s	remaining: 29.3s
# 482:	learn: 0.3332183	total: 27.3s	remaining: 29.3s
# 483:	learn: 0.3331533	total: 27.4s	remaining: 29.2s
# 484:	learn: 0.3331071	total: 27.5s	remaining: 29.2s
# 485:	learn: 0.3330255	total: 27.5s	remaining: 29.1s
# 486:	learn: 0.3330254	total: 27.6s	remaining: 29.1s
# 487:	learn: 0.3329829	total: 27.6s	remaining: 29s
# 488:	learn: 0.3323703	total: 27.7s	remaining: 29s
# 489:	learn: 0.3323703	total: 27.8s	remaining: 28.9s
# 490:	learn: 0.3323312	total: 27.8s	remaining: 28.8s
# 491:	learn: 0.3323312	total: 27.9s	remaining: 28.8s
# 492:	learn: 0.3323312	total: 27.9s	remaining: 28.7s
# 493:	learn: 0.3323312	total: 27.9s	remaining: 28.6s
# 494:	learn: 0.3321306	total: 28s	remaining: 28.6s
# 495:	learn: 0.3321306	total: 28s	remaining: 28.5s
# 496:	learn: 0.3321306	total: 28.1s	remaining: 28.4s
# 497:	learn: 0.3321306	total: 28.1s	remaining: 28.4s
# 498:	learn: 0.3321306	total: 28.2s	remaining: 28.3s
# 499:	learn: 0.3321306	total: 28.2s	remaining: 28.2s
# 500:	learn: 0.3321306	total: 28.2s	remaining: 28.1s
# 501:	learn: 0.3321306	total: 28.3s	remaining: 28.1s
# 502:	learn: 0.3320785	total: 28.3s	remaining: 28s
# 503:	learn: 0.3320785	total: 28.4s	remaining: 27.9s
# 504:	learn: 0.3319197	total: 28.5s	remaining: 27.9s
# 505:	learn: 0.3318415	total: 28.5s	remaining: 27.8s
# 506:	learn: 0.3317658	total: 28.6s	remaining: 27.8s
# 507:	learn: 0.3317658	total: 28.6s	remaining: 27.7s
# 508:	learn: 0.3317035	total: 28.7s	remaining: 27.7s
# 509:	learn: 0.3316286	total: 28.7s	remaining: 27.6s
# 510:	learn: 0.3316286	total: 28.8s	remaining: 27.5s
# 511:	learn: 0.3316286	total: 28.8s	remaining: 27.5s
# 512:	learn: 0.3316286	total: 28.8s	remaining: 27.4s
# 513:	learn: 0.3316286	total: 28.9s	remaining: 27.3s
# 514:	learn: 0.3314379	total: 28.9s	remaining: 27.3s
# 515:	learn: 0.3312631	total: 29s	remaining: 27.2s
# 516:	learn: 0.3312631	total: 29s	remaining: 27.1s
# 517:	learn: 0.3312630	total: 29.1s	remaining: 27.1s
# 518:	learn: 0.3312630	total: 29.1s	remaining: 27s
# 519:	learn: 0.3312630	total: 29.2s	remaining: 26.9s
# 520:	learn: 0.3312630	total: 29.2s	remaining: 26.9s
# 521:	learn: 0.3310890	total: 29.3s	remaining: 26.9s
# 522:	learn: 0.3310890	total: 29.4s	remaining: 26.8s
# 523:	learn: 0.3310890	total: 29.5s	remaining: 26.8s
# 524:	learn: 0.3310889	total: 29.5s	remaining: 26.7s
# 525:	learn: 0.3310889	total: 29.6s	remaining: 26.7s
# 526:	learn: 0.3310889	total: 29.7s	remaining: 26.6s
# 527:	learn: 0.3310889	total: 29.7s	remaining: 26.6s
# 528:	learn: 0.3310889	total: 29.8s	remaining: 26.6s
# 529:	learn: 0.3310498	total: 29.9s	remaining: 26.5s
# 530:	learn: 0.3310498	total: 30s	remaining: 26.5s
# 531:	learn: 0.3309055	total: 30.1s	remaining: 26.5s
# 532:	learn: 0.3309055	total: 30.2s	remaining: 26.5s
# 533:	learn: 0.3309055	total: 30.2s	remaining: 26.4s
# 534:	learn: 0.3309055	total: 30.3s	remaining: 26.3s
# 535:	learn: 0.3309055	total: 30.3s	remaining: 26.3s
# 536:	learn: 0.3308332	total: 30.4s	remaining: 26.2s
# 537:	learn: 0.3308332	total: 30.4s	remaining: 26.1s
# 538:	learn: 0.3307972	total: 30.5s	remaining: 26.1s
# 539:	learn: 0.3307972	total: 30.6s	remaining: 26s
# 540:	learn: 0.3306614	total: 30.6s	remaining: 26s
# 541:	learn: 0.3306614	total: 30.7s	remaining: 25.9s
# 542:	learn: 0.3305136	total: 30.7s	remaining: 25.9s
# 543:	learn: 0.3304812	total: 30.8s	remaining: 25.8s
# 544:	learn: 0.3304518	total: 30.9s	remaining: 25.8s
# 545:	learn: 0.3304518	total: 30.9s	remaining: 25.7s
# 546:	learn: 0.3304252	total: 31s	remaining: 25.7s
# 547:	learn: 0.3302869	total: 31.2s	remaining: 25.7s
# 548:	learn: 0.3302558	total: 31.3s	remaining: 25.7s
# 549:	learn: 0.3302346	total: 31.3s	remaining: 25.6s
# 550:	learn: 0.3302346	total: 31.4s	remaining: 25.6s
# 551:	learn: 0.3302346	total: 31.5s	remaining: 25.5s
# 552:	learn: 0.3300319	total: 31.6s	remaining: 25.5s
# 553:	learn: 0.3299788	total: 31.6s	remaining: 25.5s
# 554:	learn: 0.3299108	total: 31.7s	remaining: 25.4s
# 555:	learn: 0.3299108	total: 31.8s	remaining: 25.4s
# 556:	learn: 0.3299108	total: 31.8s	remaining: 25.3s
# 557:	learn: 0.3299108	total: 31.9s	remaining: 25.3s
# 558:	learn: 0.3299108	total: 31.9s	remaining: 25.2s
# 559:	learn: 0.3299108	total: 32s	remaining: 25.1s
# 560:	learn: 0.3299107	total: 32s	remaining: 25s
# 561:	learn: 0.3298856	total: 32.1s	remaining: 25s
# 562:	learn: 0.3298408	total: 32.1s	remaining: 24.9s
# 563:	learn: 0.3298408	total: 32.2s	remaining: 24.9s
# 564:	learn: 0.3298408	total: 32.2s	remaining: 24.8s
# 565:	learn: 0.3298305	total: 32.3s	remaining: 24.8s
# 566:	learn: 0.3298305	total: 32.4s	remaining: 24.7s
# 567:	learn: 0.3297832	total: 32.4s	remaining: 24.6s
# 568:	learn: 0.3297832	total: 32.4s	remaining: 24.6s
# 569:	learn: 0.3297463	total: 32.5s	remaining: 24.5s
# 570:	learn: 0.3297034	total: 32.5s	remaining: 24.4s
# 571:	learn: 0.3297034	total: 32.6s	remaining: 24.4s
# 572:	learn: 0.3297034	total: 32.6s	remaining: 24.3s
# 573:	learn: 0.3297034	total: 32.7s	remaining: 24.3s
# 574:	learn: 0.3297034	total: 32.7s	remaining: 24.2s
# 575:	learn: 0.3297034	total: 32.8s	remaining: 24.1s
# 576:	learn: 0.3296645	total: 32.8s	remaining: 24.1s
# 577:	learn: 0.3296645	total: 32.8s	remaining: 24s
# 578:	learn: 0.3296470	total: 32.9s	remaining: 23.9s
# 579:	learn: 0.3296222	total: 32.9s	remaining: 23.9s
# 580:	learn: 0.3296222	total: 33s	remaining: 23.8s
# 581:	learn: 0.3296222	total: 33s	remaining: 23.7s
# 582:	learn: 0.3296222	total: 33.1s	remaining: 23.7s
# 583:	learn: 0.3296222	total: 33.1s	remaining: 23.6s
# 584:	learn: 0.3296221	total: 33.2s	remaining: 23.5s
# 585:	learn: 0.3295794	total: 33.2s	remaining: 23.5s
# 586:	learn: 0.3295752	total: 33.3s	remaining: 23.4s
# 587:	learn: 0.3295752	total: 33.3s	remaining: 23.4s
# 588:	learn: 0.3295369	total: 33.4s	remaining: 23.3s
# 589:	learn: 0.3295369	total: 33.4s	remaining: 23.2s
# 590:	learn: 0.3293121	total: 33.5s	remaining: 23.2s
# 591:	learn: 0.3288585	total: 33.6s	remaining: 23.1s
# 592:	learn: 0.3288585	total: 33.6s	remaining: 23.1s
# 593:	learn: 0.3288585	total: 33.6s	remaining: 23s
# 594:	learn: 0.3288585	total: 33.7s	remaining: 22.9s
# 595:	learn: 0.3288401	total: 33.7s	remaining: 22.9s
# 596:	learn: 0.3288401	total: 33.8s	remaining: 22.8s
# 597:	learn: 0.3287235	total: 33.9s	remaining: 22.8s
# 598:	learn: 0.3287235	total: 33.9s	remaining: 22.7s
# 599:	learn: 0.3287235	total: 33.9s	remaining: 22.6s
# 600:	learn: 0.3287235	total: 34s	remaining: 22.6s
# 601:	learn: 0.3287235	total: 34s	remaining: 22.5s
# 602:	learn: 0.3287235	total: 34.1s	remaining: 22.4s
# 603:	learn: 0.3287235	total: 34.1s	remaining: 22.4s
# 604:	learn: 0.3287086	total: 34.2s	remaining: 22.3s
# 605:	learn: 0.3287086	total: 34.2s	remaining: 22.2s
# 606:	learn: 0.3286425	total: 34.2s	remaining: 22.2s
# 607:	learn: 0.3286425	total: 34.3s	remaining: 22.1s
# 608:	learn: 0.3286425	total: 34.3s	remaining: 22s
# 609:	learn: 0.3286425	total: 34.4s	remaining: 22s
# 610:	learn: 0.3286425	total: 34.4s	remaining: 21.9s
# 611:	learn: 0.3286425	total: 34.5s	remaining: 21.8s
# 612:	learn: 0.3286425	total: 34.5s	remaining: 21.8s
# 613:	learn: 0.3286425	total: 34.6s	remaining: 21.7s
# 614:	learn: 0.3286425	total: 34.7s	remaining: 21.7s
# 615:	learn: 0.3286425	total: 34.8s	remaining: 21.7s
# 616:	learn: 0.3286378	total: 34.9s	remaining: 21.6s
# 617:	learn: 0.3286378	total: 35s	remaining: 21.6s
# 618:	learn: 0.3286378	total: 35s	remaining: 21.6s
# 619:	learn: 0.3286175	total: 35.1s	remaining: 21.5s
# 620:	learn: 0.3286175	total: 35.2s	remaining: 21.5s
# 621:	learn: 0.3286175	total: 35.3s	remaining: 21.4s
# 622:	learn: 0.3286175	total: 35.3s	remaining: 21.4s
# 623:	learn: 0.3286175	total: 35.4s	remaining: 21.3s
# 624:	learn: 0.3285991	total: 35.5s	remaining: 21.3s
# 625:	learn: 0.3285991	total: 35.5s	remaining: 21.2s
# 626:	learn: 0.3285991	total: 35.6s	remaining: 21.2s
# 627:	learn: 0.3285703	total: 35.7s	remaining: 21.1s
# 628:	learn: 0.3285703	total: 35.8s	remaining: 21.1s
# 629:	learn: 0.3285426	total: 35.9s	remaining: 21.1s
# 630:	learn: 0.3285426	total: 35.9s	remaining: 21s
# 631:	learn: 0.3285426	total: 36s	remaining: 20.9s
# 632:	learn: 0.3284793	total: 36s	remaining: 20.9s
# 633:	learn: 0.3277538	total: 36.2s	remaining: 20.9s
# 634:	learn: 0.3277538	total: 36.3s	remaining: 20.8s
# 635:	learn: 0.3277538	total: 36.3s	remaining: 20.8s
# 636:	learn: 0.3276897	total: 36.4s	remaining: 20.7s
# 637:	learn: 0.3276897	total: 36.4s	remaining: 20.7s
# 638:	learn: 0.3276897	total: 36.5s	remaining: 20.6s
# 639:	learn: 0.3276897	total: 36.5s	remaining: 20.5s
# 640:	learn: 0.3276897	total: 36.6s	remaining: 20.5s
# 641:	learn: 0.3276698	total: 36.6s	remaining: 20.4s
# 642:	learn: 0.3276340	total: 36.7s	remaining: 20.4s
# 643:	learn: 0.3276297	total: 36.7s	remaining: 20.3s
# 644:	learn: 0.3276297	total: 36.8s	remaining: 20.3s
# 645:	learn: 0.3276297	total: 36.9s	remaining: 20.2s
# 646:	learn: 0.3269606	total: 36.9s	remaining: 20.2s
# 647:	learn: 0.3269606	total: 37.1s	remaining: 20.1s
# 648:	learn: 0.3269606	total: 37.2s	remaining: 20.1s
# 649:	learn: 0.3268478	total: 37.2s	remaining: 20.1s
# 650:	learn: 0.3268478	total: 37.3s	remaining: 20s
# 651:	learn: 0.3268478	total: 37.4s	remaining: 20s
# 652:	learn: 0.3268478	total: 37.5s	remaining: 19.9s
# 653:	learn: 0.3268478	total: 37.5s	remaining: 19.9s
# 654:	learn: 0.3268478	total: 37.6s	remaining: 19.8s
# 655:	learn: 0.3268478	total: 37.6s	remaining: 19.7s
# 656:	learn: 0.3268478	total: 37.7s	remaining: 19.7s
# 657:	learn: 0.3267223	total: 37.8s	remaining: 19.6s
# 658:	learn: 0.3267223	total: 37.8s	remaining: 19.6s
# 659:	learn: 0.3267223	total: 37.9s	remaining: 19.5s
# 660:	learn: 0.3267223	total: 37.9s	remaining: 19.4s
# 661:	learn: 0.3267202	total: 38s	remaining: 19.4s
# 662:	learn: 0.3267202	total: 38s	remaining: 19.3s
# 663:	learn: 0.3267202	total: 38.1s	remaining: 19.3s
# 664:	learn: 0.3267202	total: 38.2s	remaining: 19.2s
# 665:	learn: 0.3267202	total: 38.2s	remaining: 19.2s
# 666:	learn: 0.3267049	total: 38.2s	remaining: 19.1s
# 667:	learn: 0.3266760	total: 38.3s	remaining: 19s
# 668:	learn: 0.3266760	total: 38.3s	remaining: 19s
# 669:	learn: 0.3266760	total: 38.4s	remaining: 18.9s
# 670:	learn: 0.3265716	total: 38.4s	remaining: 18.8s
# 671:	learn: 0.3265573	total: 38.4s	remaining: 18.8s
# 672:	learn: 0.3265573	total: 38.5s	remaining: 18.7s
# 673:	learn: 0.3265573	total: 38.5s	remaining: 18.6s
# 674:	learn: 0.3265573	total: 38.6s	remaining: 18.6s
# 675:	learn: 0.3265573	total: 38.6s	remaining: 18.5s
# 676:	learn: 0.3265573	total: 38.7s	remaining: 18.4s
# 677:	learn: 0.3265573	total: 38.7s	remaining: 18.4s
# 678:	learn: 0.3265044	total: 38.7s	remaining: 18.3s
# 679:	learn: 0.3264760	total: 38.8s	remaining: 18.3s
# 680:	learn: 0.3264760	total: 38.8s	remaining: 18.2s
# 681:	learn: 0.3263959	total: 38.9s	remaining: 18.1s
# 682:	learn: 0.3263042	total: 38.9s	remaining: 18.1s
# 683:	learn: 0.3263042	total: 39s	remaining: 18s
# 684:	learn: 0.3263042	total: 39s	remaining: 17.9s
# 685:	learn: 0.3262343	total: 39.1s	remaining: 17.9s
# 686:	learn: 0.3261873	total: 39.1s	remaining: 17.8s
# 687:	learn: 0.3261873	total: 39.2s	remaining: 17.8s
# 688:	learn: 0.3261873	total: 39.2s	remaining: 17.7s
# 689:	learn: 0.3261733	total: 39.3s	remaining: 17.6s
# 690:	learn: 0.3261733	total: 39.3s	remaining: 17.6s
# 691:	learn: 0.3261484	total: 39.3s	remaining: 17.5s
# 692:	learn: 0.3261484	total: 39.4s	remaining: 17.4s
# 693:	learn: 0.3260031	total: 39.5s	remaining: 17.4s
# 694:	learn: 0.3259769	total: 39.5s	remaining: 17.3s
# 695:	learn: 0.3259769	total: 39.6s	remaining: 17.3s
# 696:	learn: 0.3259639	total: 39.6s	remaining: 17.2s
# 697:	learn: 0.3259639	total: 39.6s	remaining: 17.2s
# 698:	learn: 0.3259639	total: 39.7s	remaining: 17.1s
# 699:	learn: 0.3259521	total: 39.7s	remaining: 17s
# 700:	learn: 0.3259305	total: 39.8s	remaining: 17s
# 701:	learn: 0.3259305	total: 39.8s	remaining: 16.9s
# 702:	learn: 0.3259305	total: 39.9s	remaining: 16.8s
# 703:	learn: 0.3259305	total: 39.9s	remaining: 16.8s
# 704:	learn: 0.3259130	total: 40s	remaining: 16.7s
# 705:	learn: 0.3258219	total: 40.1s	remaining: 16.7s
# 706:	learn: 0.3258219	total: 40.2s	remaining: 16.6s
# 707:	learn: 0.3257856	total: 40.2s	remaining: 16.6s
# 708:	learn: 0.3257817	total: 40.3s	remaining: 16.5s
# 709:	learn: 0.3257817	total: 40.3s	remaining: 16.5s
# 710:	learn: 0.3257817	total: 40.4s	remaining: 16.4s
# 711:	learn: 0.3257817	total: 40.5s	remaining: 16.4s
# 712:	learn: 0.3257817	total: 40.6s	remaining: 16.3s
# 713:	learn: 0.3257817	total: 40.6s	remaining: 16.3s
# 714:	learn: 0.3257817	total: 40.7s	remaining: 16.2s
# 715:	learn: 0.3257595	total: 40.7s	remaining: 16.1s
# 716:	learn: 0.3257595	total: 40.7s	remaining: 16.1s
# 717:	learn: 0.3256181	total: 40.8s	remaining: 16s
# 718:	learn: 0.3252588	total: 40.9s	remaining: 16s
# 719:	learn: 0.3252587	total: 40.9s	remaining: 15.9s
# 720:	learn: 0.3252550	total: 41s	remaining: 15.8s
# 721:	learn: 0.3252549	total: 41s	remaining: 15.8s
# 722:	learn: 0.3252323	total: 41.1s	remaining: 15.7s
# 723:	learn: 0.3252159	total: 41.1s	remaining: 15.7s
# 724:	learn: 0.3249544	total: 41.2s	remaining: 15.6s
# 725:	learn: 0.3249544	total: 41.2s	remaining: 15.5s
# 726:	learn: 0.3249415	total: 41.2s	remaining: 15.5s
# 727:	learn: 0.3249415	total: 41.3s	remaining: 15.4s
# 728:	learn: 0.3249119	total: 41.3s	remaining: 15.4s
# 729:	learn: 0.3249118	total: 41.4s	remaining: 15.3s
# 730:	learn: 0.3249118	total: 41.4s	remaining: 15.2s
# 731:	learn: 0.3248804	total: 41.5s	remaining: 15.2s
# 732:	learn: 0.3248410	total: 41.5s	remaining: 15.1s
# 733:	learn: 0.3248410	total: 41.5s	remaining: 15.1s
# 734:	learn: 0.3248410	total: 41.6s	remaining: 15s
# 735:	learn: 0.3248317	total: 41.6s	remaining: 14.9s
# 736:	learn: 0.3248317	total: 41.7s	remaining: 14.9s
# 737:	learn: 0.3248317	total: 41.7s	remaining: 14.8s
# 738:	learn: 0.3248317	total: 41.8s	remaining: 14.7s
# 739:	learn: 0.3248317	total: 41.8s	remaining: 14.7s
# 740:	learn: 0.3247606	total: 41.9s	remaining: 14.6s
# 741:	learn: 0.3247606	total: 41.9s	remaining: 14.6s
# 742:	learn: 0.3247606	total: 42s	remaining: 14.5s
# 743:	learn: 0.3247605	total: 42s	remaining: 14.5s
# 744:	learn: 0.3247605	total: 42.1s	remaining: 14.4s
# 745:	learn: 0.3247605	total: 42.2s	remaining: 14.4s
# 746:	learn: 0.3247342	total: 42.3s	remaining: 14.3s
# 747:	learn: 0.3247342	total: 42.4s	remaining: 14.3s
# 748:	learn: 0.3247342	total: 42.4s	remaining: 14.2s
# 749:	learn: 0.3247342	total: 42.5s	remaining: 14.2s
# 750:	learn: 0.3247342	total: 42.5s	remaining: 14.1s
# 751:	learn: 0.3245361	total: 42.6s	remaining: 14s
# 752:	learn: 0.3245206	total: 42.6s	remaining: 14s
# 753:	learn: 0.3245206	total: 42.7s	remaining: 13.9s
# 754:	learn: 0.3245206	total: 42.7s	remaining: 13.9s
# 755:	learn: 0.3244624	total: 42.8s	remaining: 13.8s
# 756:	learn: 0.3244624	total: 42.8s	remaining: 13.7s
# 757:	learn: 0.3244624	total: 42.8s	remaining: 13.7s
# 758:	learn: 0.3244103	total: 42.9s	remaining: 13.6s
# 759:	learn: 0.3244103	total: 42.9s	remaining: 13.6s
# 760:	learn: 0.3243853	total: 43s	remaining: 13.5s
# 761:	learn: 0.3243853	total: 43s	remaining: 13.4s
# 762:	learn: 0.3243853	total: 43.1s	remaining: 13.4s
# 763:	learn: 0.3243724	total: 43.2s	remaining: 13.3s
# 764:	learn: 0.3243724	total: 43.2s	remaining: 13.3s
# 765:	learn: 0.3243724	total: 43.3s	remaining: 13.2s
# 766:	learn: 0.3243724	total: 43.3s	remaining: 13.2s
# 767:	learn: 0.3243724	total: 43.4s	remaining: 13.1s
# 768:	learn: 0.3243584	total: 43.5s	remaining: 13.1s
# 769:	learn: 0.3243584	total: 43.5s	remaining: 13s
# 770:	learn: 0.3243583	total: 43.6s	remaining: 12.9s
# 771:	learn: 0.3243583	total: 43.6s	remaining: 12.9s
# 772:	learn: 0.3243583	total: 43.7s	remaining: 12.8s
# 773:	learn: 0.3243583	total: 43.7s	remaining: 12.8s
# 774:	learn: 0.3243456	total: 43.7s	remaining: 12.7s
# 775:	learn: 0.3242976	total: 43.8s	remaining: 12.6s
# 776:	learn: 0.3242976	total: 43.8s	remaining: 12.6s
# 777:	learn: 0.3242976	total: 43.9s	remaining: 12.5s
# 778:	learn: 0.3242852	total: 43.9s	remaining: 12.5s
# 779:	learn: 0.3242852	total: 43.9s	remaining: 12.4s
# 780:	learn: 0.3242659	total: 44s	remaining: 12.3s
# 781:	learn: 0.3241522	total: 44s	remaining: 12.3s
# 782:	learn: 0.3241001	total: 44.1s	remaining: 12.2s
# 783:	learn: 0.3241001	total: 44.1s	remaining: 12.2s
# 784:	learn: 0.3240926	total: 44.2s	remaining: 12.1s
# 785:	learn: 0.3240926	total: 44.2s	remaining: 12s
# 786:	learn: 0.3240926	total: 44.3s	remaining: 12s
# 787:	learn: 0.3240926	total: 44.3s	remaining: 11.9s
# 788:	learn: 0.3239916	total: 44.4s	remaining: 11.9s
# 789:	learn: 0.3239916	total: 44.4s	remaining: 11.8s
# 790:	learn: 0.3239916	total: 44.5s	remaining: 11.8s
# 791:	learn: 0.3239755	total: 44.5s	remaining: 11.7s
# 792:	learn: 0.3239755	total: 44.6s	remaining: 11.6s
# 793:	learn: 0.3239755	total: 44.6s	remaining: 11.6s
# 794:	learn: 0.3239755	total: 44.6s	remaining: 11.5s
# 795:	learn: 0.3239541	total: 44.7s	remaining: 11.5s
# 796:	learn: 0.3239541	total: 44.7s	remaining: 11.4s
# 797:	learn: 0.3239541	total: 44.8s	remaining: 11.3s
# 798:	learn: 0.3239348	total: 44.8s	remaining: 11.3s
# 799:	learn: 0.3239134	total: 44.9s	remaining: 11.2s
# 800:	learn: 0.3239134	total: 45s	remaining: 11.2s
# 801:	learn: 0.3239134	total: 45s	remaining: 11.1s
# 802:	learn: 0.3238555	total: 45s	remaining: 11.1s
# 803:	learn: 0.3238555	total: 45.1s	remaining: 11s
# 804:	learn: 0.3238555	total: 45.1s	remaining: 10.9s
# 805:	learn: 0.3238555	total: 45.2s	remaining: 10.9s
# 806:	learn: 0.3238555	total: 45.2s	remaining: 10.8s
# 807:	learn: 0.3238315	total: 45.2s	remaining: 10.7s
# 808:	learn: 0.3238315	total: 45.3s	remaining: 10.7s
# 809:	learn: 0.3237946	total: 45.3s	remaining: 10.6s
# 810:	learn: 0.3237946	total: 45.4s	remaining: 10.6s
# 811:	learn: 0.3237946	total: 45.4s	remaining: 10.5s
# 812:	learn: 0.3237946	total: 45.4s	remaining: 10.5s
# 813:	learn: 0.3237946	total: 45.5s	remaining: 10.4s
# 814:	learn: 0.3237946	total: 45.5s	remaining: 10.3s
# 815:	learn: 0.3237946	total: 45.6s	remaining: 10.3s
# 816:	learn: 0.3237946	total: 45.6s	remaining: 10.2s
# 817:	learn: 0.3237946	total: 45.7s	remaining: 10.2s
# 818:	learn: 0.3237878	total: 45.7s	remaining: 10.1s
# 819:	learn: 0.3235565	total: 45.8s	remaining: 10s
# 820:	learn: 0.3235360	total: 45.8s	remaining: 9.99s
# 821:	learn: 0.3235325	total: 45.9s	remaining: 9.93s
# 822:	learn: 0.3235203	total: 45.9s	remaining: 9.87s
# 823:	learn: 0.3235203	total: 45.9s	remaining: 9.81s
# 824:	learn: 0.3235045	total: 46s	remaining: 9.75s
# 825:	learn: 0.3235045	total: 46s	remaining: 9.69s
# 826:	learn: 0.3234924	total: 46.1s	remaining: 9.64s
# 827:	learn: 0.3234924	total: 46.1s	remaining: 9.58s
# 828:	learn: 0.3234924	total: 46.2s	remaining: 9.53s
# 829:	learn: 0.3234924	total: 46.2s	remaining: 9.47s
# 830:	learn: 0.3234924	total: 46.3s	remaining: 9.41s
# 831:	learn: 0.3234924	total: 46.3s	remaining: 9.35s
# 832:	learn: 0.3233349	total: 46.3s	remaining: 9.29s
# 833:	learn: 0.3229355	total: 46.4s	remaining: 9.23s
# 834:	learn: 0.3229355	total: 46.5s	remaining: 9.18s
# 835:	learn: 0.3229312	total: 46.5s	remaining: 9.12s
# 836:	learn: 0.3229127	total: 46.6s	remaining: 9.07s
# 837:	learn: 0.3229040	total: 46.6s	remaining: 9.01s
# 838:	learn: 0.3228617	total: 46.7s	remaining: 8.95s
# 839:	learn: 0.3228577	total: 46.7s	remaining: 8.9s
# 840:	learn: 0.3228426	total: 46.8s	remaining: 8.84s
# 841:	learn: 0.3228315	total: 46.8s	remaining: 8.79s
# 842:	learn: 0.3228315	total: 46.9s	remaining: 8.73s
# 843:	learn: 0.3228315	total: 46.9s	remaining: 8.67s
# 844:	learn: 0.3228315	total: 47s	remaining: 8.62s
# 845:	learn: 0.3228315	total: 47s	remaining: 8.56s
# 846:	learn: 0.3228172	total: 47s	remaining: 8.5s
# 847:	learn: 0.3228172	total: 47.1s	remaining: 8.44s
# 848:	learn: 0.3228172	total: 47.1s	remaining: 8.38s
# 849:	learn: 0.3228138	total: 47.2s	remaining: 8.33s
# 850:	learn: 0.3228138	total: 47.2s	remaining: 8.27s
# 851:	learn: 0.3228138	total: 47.3s	remaining: 8.21s
# 852:	learn: 0.3228010	total: 47.4s	remaining: 8.16s
# 853:	learn: 0.3228010	total: 47.4s	remaining: 8.11s
# 854:	learn: 0.3228010	total: 47.5s	remaining: 8.05s
# 855:	learn: 0.3228010	total: 47.5s	remaining: 8s
# 856:	learn: 0.3227853	total: 47.6s	remaining: 7.94s
# 857:	learn: 0.3227853	total: 47.6s	remaining: 7.88s
# 858:	learn: 0.3227853	total: 47.7s	remaining: 7.82s
# 859:	learn: 0.3227356	total: 47.7s	remaining: 7.77s
# 860:	learn: 0.3227240	total: 47.8s	remaining: 7.71s
# 861:	learn: 0.3227240	total: 47.8s	remaining: 7.65s
# 862:	learn: 0.3227240	total: 47.8s	remaining: 7.59s
# 863:	learn: 0.3227240	total: 47.9s	remaining: 7.54s
# 864:	learn: 0.3227120	total: 47.9s	remaining: 7.48s
# 865:	learn: 0.3227120	total: 48s	remaining: 7.42s
# 866:	learn: 0.3226771	total: 48s	remaining: 7.37s
# 867:	learn: 0.3223732	total: 48.1s	remaining: 7.31s
# 868:	learn: 0.3223732	total: 48.1s	remaining: 7.25s
# 869:	learn: 0.3223732	total: 48.1s	remaining: 7.19s
# 870:	learn: 0.3223732	total: 48.2s	remaining: 7.14s
# 871:	learn: 0.3223732	total: 48.3s	remaining: 7.08s
# 872:	learn: 0.3223732	total: 48.3s	remaining: 7.03s
# 873:	learn: 0.3222405	total: 48.4s	remaining: 6.97s
# 874:	learn: 0.3222405	total: 48.4s	remaining: 6.92s
# 875:	learn: 0.3222405	total: 48.5s	remaining: 6.86s
# 876:	learn: 0.3218982	total: 48.5s	remaining: 6.81s
# 877:	learn: 0.3218858	total: 48.6s	remaining: 6.75s
# 878:	learn: 0.3218858	total: 48.6s	remaining: 6.69s
# 879:	learn: 0.3218858	total: 48.7s	remaining: 6.63s
# 880:	learn: 0.3218858	total: 48.7s	remaining: 6.58s
# 881:	learn: 0.3218858	total: 48.7s	remaining: 6.52s
# 882:	learn: 0.3218858	total: 48.8s	remaining: 6.46s
# 883:	learn: 0.3217093	total: 48.8s	remaining: 6.41s
# 884:	learn: 0.3217093	total: 48.8s	remaining: 6.35s
# 885:	learn: 0.3217093	total: 48.9s	remaining: 6.29s
# 886:	learn: 0.3217093	total: 48.9s	remaining: 6.23s
# 887:	learn: 0.3217063	total: 49s	remaining: 6.18s
# 888:	learn: 0.3217063	total: 49s	remaining: 6.12s
# 889:	learn: 0.3217063	total: 49s	remaining: 6.06s
# 890:	learn: 0.3217037	total: 49.1s	remaining: 6s
# 891:	learn: 0.3217036	total: 49.1s	remaining: 5.95s
# 892:	learn: 0.3216916	total: 49.2s	remaining: 5.89s
# 893:	learn: 0.3216916	total: 49.2s	remaining: 5.83s
# 894:	learn: 0.3216916	total: 49.3s	remaining: 5.78s
# 895:	learn: 0.3216916	total: 49.4s	remaining: 5.73s
# 896:	learn: 0.3216916	total: 49.6s	remaining: 5.69s
# 897:	learn: 0.3216915	total: 49.7s	remaining: 5.65s
# 898:	learn: 0.3216712	total: 49.8s	remaining: 5.59s
# 899:	learn: 0.3216712	total: 49.9s	remaining: 5.54s
# 900:	learn: 0.3216712	total: 50s	remaining: 5.49s
# 901:	learn: 0.3216585	total: 50s	remaining: 5.43s
# 902:	learn: 0.3216422	total: 50s	remaining: 5.38s
# 903:	learn: 0.3216422	total: 50.1s	remaining: 5.32s
# 904:	learn: 0.3216422	total: 50.1s	remaining: 5.26s
# 905:	learn: 0.3216422	total: 50.2s	remaining: 5.21s
# 906:	learn: 0.3216090	total: 50.3s	remaining: 5.15s
# 907:	learn: 0.3216090	total: 50.3s	remaining: 5.1s
# 908:	learn: 0.3214698	total: 50.4s	remaining: 5.04s
# 909:	learn: 0.3214584	total: 50.4s	remaining: 4.99s
# 910:	learn: 0.3214556	total: 50.5s	remaining: 4.94s
# 911:	learn: 0.3214556	total: 50.6s	remaining: 4.88s
# 912:	learn: 0.3214556	total: 50.6s	remaining: 4.82s
# 913:	learn: 0.3214556	total: 50.7s	remaining: 4.77s
# 914:	learn: 0.3214377	total: 50.7s	remaining: 4.71s
# 915:	learn: 0.3214377	total: 50.7s	remaining: 4.65s
# 916:	learn: 0.3214200	total: 50.8s	remaining: 4.6s
# 917:	learn: 0.3214200	total: 50.8s	remaining: 4.54s
# 918:	learn: 0.3214060	total: 50.9s	remaining: 4.48s
# 919:	learn: 0.3214060	total: 50.9s	remaining: 4.43s
# 920:	learn: 0.3213963	total: 51s	remaining: 4.37s
# 921:	learn: 0.3213963	total: 51s	remaining: 4.32s
# 922:	learn: 0.3213963	total: 51.1s	remaining: 4.26s
# 923:	learn: 0.3213963	total: 51.1s	remaining: 4.2s
# 924:	learn: 0.3213962	total: 51.1s	remaining: 4.14s
# 925:	learn: 0.3213962	total: 51.2s	remaining: 4.09s
# 926:	learn: 0.3213962	total: 51.2s	remaining: 4.03s
# 927:	learn: 0.3213962	total: 51.3s	remaining: 3.98s
# 928:	learn: 0.3213962	total: 51.3s	remaining: 3.92s
# 929:	learn: 0.3213962	total: 51.3s	remaining: 3.86s
# 930:	learn: 0.3213957	total: 51.4s	remaining: 3.81s
# 931:	learn: 0.3213957	total: 51.4s	remaining: 3.75s
# 932:	learn: 0.3213957	total: 51.5s	remaining: 3.69s
# 933:	learn: 0.3213957	total: 51.5s	remaining: 3.64s
# 934:	learn: 0.3213957	total: 51.6s	remaining: 3.58s
# 935:	learn: 0.3213957	total: 51.6s	remaining: 3.53s
# 936:	learn: 0.3213957	total: 51.6s	remaining: 3.47s
# 937:	learn: 0.3213932	total: 51.7s	remaining: 3.42s
# 938:	learn: 0.3213932	total: 51.8s	remaining: 3.36s
# 939:	learn: 0.3213895	total: 51.8s	remaining: 3.31s
# 940:	learn: 0.3213895	total: 51.9s	remaining: 3.25s
# 941:	learn: 0.3213624	total: 51.9s	remaining: 3.2s
# 942:	learn: 0.3213624	total: 52s	remaining: 3.14s
# 943:	learn: 0.3213519	total: 52s	remaining: 3.09s
# 944:	learn: 0.3213519	total: 52.1s	remaining: 3.03s
# 945:	learn: 0.3213519	total: 52.1s	remaining: 2.97s
# 946:	learn: 0.3213519	total: 52.2s	remaining: 2.92s
# 947:	learn: 0.3213519	total: 52.2s	remaining: 2.86s
# 948:	learn: 0.3213519	total: 52.2s	remaining: 2.81s
# 949:	learn: 0.3213519	total: 52.3s	remaining: 2.75s
# 950:	learn: 0.3213519	total: 52.3s	remaining: 2.69s
# 951:	learn: 0.3213519	total: 52.3s	remaining: 2.64s
# 952:	learn: 0.3213519	total: 52.4s	remaining: 2.58s
# 953:	learn: 0.3213349	total: 52.4s	remaining: 2.53s
# 954:	learn: 0.3213349	total: 52.5s	remaining: 2.47s
# 955:	learn: 0.3213349	total: 52.5s	remaining: 2.42s
# 956:	learn: 0.3213349	total: 52.5s	remaining: 2.36s
# 957:	learn: 0.3213349	total: 52.6s	remaining: 2.31s
# 958:	learn: 0.3213194	total: 52.6s	remaining: 2.25s
# 959:	learn: 0.3213194	total: 52.7s	remaining: 2.19s
# 960:	learn: 0.3213194	total: 52.7s	remaining: 2.14s
# 961:	learn: 0.3213194	total: 52.7s	remaining: 2.08s
# 962:	learn: 0.3212228	total: 52.8s	remaining: 2.03s
# 963:	learn: 0.3212228	total: 52.8s	remaining: 1.97s
# 964:	learn: 0.3212040	total: 52.9s	remaining: 1.92s
# 965:	learn: 0.3212040	total: 52.9s	remaining: 1.86s
# 966:	learn: 0.3212040	total: 52.9s	remaining: 1.81s
# 967:	learn: 0.3212040	total: 53s	remaining: 1.75s
# 968:	learn: 0.3212040	total: 53s	remaining: 1.7s
# 969:	learn: 0.3212040	total: 53.1s	remaining: 1.64s
# 970:	learn: 0.3212040	total: 53.1s	remaining: 1.59s
# 971:	learn: 0.3212040	total: 53.2s	remaining: 1.53s
# 972:	learn: 0.3211962	total: 53.2s	remaining: 1.48s
# 973:	learn: 0.3211962	total: 53.3s	remaining: 1.42s
# 974:	learn: 0.3210910	total: 53.3s	remaining: 1.37s
# 975:	learn: 0.3208606	total: 53.5s	remaining: 1.31s
# 976:	learn: 0.3208584	total: 53.5s	remaining: 1.26s
# 977:	learn: 0.3207745	total: 53.6s	remaining: 1.21s
# 978:	learn: 0.3207745	total: 53.6s	remaining: 1.15s
# 979:	learn: 0.3207744	total: 53.7s	remaining: 1.09s
# 980:	learn: 0.3207744	total: 53.7s	remaining: 1.04s
# 981:	learn: 0.3206921	total: 53.8s	remaining: 986ms
# 982:	learn: 0.3206582	total: 53.9s	remaining: 932ms
# 983:	learn: 0.3206582	total: 53.9s	remaining: 877ms
# 984:	learn: 0.3206582	total: 54s	remaining: 822ms
# 985:	learn: 0.3206582	total: 54s	remaining: 767ms
# 986:	learn: 0.3206582	total: 54.1s	remaining: 712ms
# 987:	learn: 0.3206354	total: 54.1s	remaining: 658ms
# 988:	learn: 0.3206354	total: 54.2s	remaining: 603ms
# 989:	learn: 0.3206354	total: 54.3s	remaining: 548ms
# 990:	learn: 0.3206354	total: 54.3s	remaining: 493ms
# 991:	learn: 0.3206354	total: 54.4s	remaining: 439ms
# 992:	learn: 0.3206354	total: 54.5s	remaining: 384ms
# 993:	learn: 0.3206187	total: 54.6s	remaining: 329ms
# 994:	learn: 0.3206187	total: 54.6s	remaining: 274ms
# 995:	learn: 0.3206187	total: 54.7s	remaining: 220ms
# 996:	learn: 0.3206166	total: 54.7s	remaining: 165ms
# 997:	learn: 0.3206166	total: 54.8s	remaining: 110ms
# 998:	learn: 0.3206166	total: 54.8s	remaining: 54.9ms
# 999:	learn: 0.3206166	total: 54.9s	remaining: 0us
# Final Model trained on full data
# ------
# Accuracy on testing data: 0.8730
# F-score on testing data: 0.7571
#
# Final Model trained on reduced data
# ------
# Accuracy on testing data: 0.8520
# F-score on testing data: 0.7179

# %% [markdown]
# ### Question 8 - Effects of Feature Selection
#
# * How does the final model's F-score and accuracy score on the reduced data using only five features compare to those same scores when all features are used?
# * If training time was a factor, would you consider using the reduced data as your training set?

# %% [markdown]
# **Answer:**
# - the final model's F-score and accuracy score on the reduced data using only five features is a lot less than when we used all features.
# - no becasue the accuracy and fscore is a lot higher when we used all features at the cost of slightly more time

# %% [markdown]
# > **Note**: Once you have completed all of the code implementations and successfully answered each question above, you may finalize your work by exporting the iPython Notebook as an HTML document. You can do this by using the menu above and navigating to
# **File -> Download as -> HTML (.html)**. Include the finished document along with this notebook as your submission.

# %% [markdown]
# ## Before You Submit
# You will also need run the following in order to convert the Jupyter notebook into HTML, so that your submission will include both files.

# %%
# !!jupyter nbconvert *.ipynb
# Out:
# ['Traceback (most recent call last):',
#  '  File "C:\\Users\\Gehan\\anaconda3\\Scripts\\jupyter-nbconvert-script.py", line 10, in <module>',
#  '    sys.exit(main())',
#  '  File "C:\\Users\\Gehan\\anaconda3\\lib\\site-packages\\jupyter_core\\application.py", line 269, in launch_instance',
#  '    return super().launch_instance(argv=argv, **kwargs)',
#  '  File "C:\\Users\\Gehan\\anaconda3\\lib\\site-packages\\traitlets\\config\\application.py", line 846, in launch_instance',
#  '    app.start()',
#  '  File "C:\\Users\\Gehan\\anaconda3\\lib\\site-packages\\nbconvert\\nbconvertapp.py", line 369, in start',
#  '    self.convert_notebooks()',
#  '  File "C:\\Users\\Gehan\\anaconda3\\lib\\site-packages\\nbconvert\\nbconvertapp.py", line 529, in convert_notebooks',
#  '    raise ValueError(',
#  "ValueError: Please specify an output format with '--to <format>'.",
#  "The following formats are available: ['asciidoc', 'custom', 'html', 'latex', 'markdown', 'notebook', 'pdf', 'python', 'rst', 'script', 'slides', 'webpdf']"]
